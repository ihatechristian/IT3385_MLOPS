# %%
# --- Step 0: Imports ---
import pandas as pd
from pycaret.classification import *
import mlflow
import pathlib
import shutil

# %%
mlflow.__version__
# Out:
# '2.12.1'

# %%
# --- Step 1: Clean MLflow trash directory (Windows fix) ---
trash_path = pathlib.Path('../mlruns/.trash')
if trash_path.exists():
    try:
        shutil.rmtree(trash_path)
        print("MLflow '.trash' directory cleaned up successfully.")
    except Exception as e:
        print(f"Error cleaning up MLflow '.trash' directory: {e}")

# --- Step 2: Load dataset ---
try:
    df = pd.read_csv('../data/03_Wheat_Seeds.csv')
    print("Dataset loaded successfully.")
except FileNotFoundError:
    print("Error: '03_Wheat_Seeds.csv' not found.")
    exit()

# --- Step 2a: Drop highly correlated / unwanted columns ---
# Keep: Area, Compactness, Length, AsymmetryCoeff, Groove, Type
columns_to_keep = ['Area', 'Compactness', 'Length', 'AsymmetryCoeff', 'Groove', 'Type']
df = df[columns_to_keep]
print(f"Columns retained for modeling: {list(df.columns)}")


# --- Step 3: Configure MLflow tracking ---
mlruns_path = pathlib.Path('mlruns').resolve().as_uri()
mlflow.set_tracking_uri(mlruns_path)
mlflow.set_experiment("Wheat Seeds Classification")
print(f"MLflow tracking URI set to: {mlflow.get_tracking_uri()}")

# --- Step 4: Run experiment with PyCaret auto-logging ---
print("\nSetting up PyCaret environment with MLflow logging...")
s = setup(
    data=df,
    target='Type',
    session_id=123,
    log_experiment=True,         # enable PyCaret auto-logging
    log_profile=False,
    experiment_name='Wheat Seeds Classification'
)
print("Setup complete.")

# Step 4a: Compare models (auto-logged to MLflow)
print("\nComparing models...")
best_model = compare_models()
print("Best model:", best_model)

# Step 4b: Tune best model (auto-logged to MLflow)
print("\nTuning best model...")
tuned_best_model = tune_model(best_model)
print("Tuned model:", tuned_best_model)

# Step 4c: Evaluate model (plots auto-logged to MLflow)
print("\nEvaluating tuned model...")
evaluate_model(tuned_best_model)

# Step 4d: Finalize and save model (PyCaret logs automatically)
print("\nFinalizing model for deployment...")
final_model = finalize_model(tuned_best_model)

# Save the model locally for serving later
save_model(final_model, 'models/wheat_seeds')
print("Final model saved as 'wheat_seeds.pkl'.")

print("\n Experiment finished — all metrics, plots, and models logged automatically to MLflow.")
# Out:
# 2025/08/30 00:43:14 INFO mlflow.tracking.fluent: Experiment with name 'Wheat Seeds Classification' does not exist. Creating a new experiment.
# Dataset loaded successfully.
# Columns retained for modeling: ['Area', 'Compactness', 'Length', 'AsymmetryCoeff', 'Groove', 'Type']
# MLflow tracking URI set to: file:///C:/Users/chris/OneDrive/Desktop/School%20Work/Year%203%20Sem%201/MLOPS/Assignment/mlruns
#
# Setting up PyCaret environment with MLflow logging...
# <style type="text/css">
# #T_5368e_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5368e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5368e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5368e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5368e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5368e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5368e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5368e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5368e_row1_col1" class="data row1 col1" >Type</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5368e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5368e_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5368e_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_5368e_row3_col1" class="data row3 col1" >1: 0, 2: 1, 3: 2</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5368e_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_5368e_row4_col1" class="data row4 col1" >(199, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5368e_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_5368e_row5_col1" class="data row5 col1" >(199, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5368e_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_5368e_row6_col1" class="data row6 col1" >(139, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5368e_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_5368e_row7_col1" class="data row7 col1" >(60, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5368e_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_5368e_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5368e_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_5368e_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5368e_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_5368e_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5368e_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_5368e_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5368e_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_5368e_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5368e_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_5368e_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5368e_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_5368e_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5368e_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_5368e_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5368e_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_5368e_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5368e_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_5368e_row17_col1" class="data row17 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5368e_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_5368e_row18_col1" class="data row18 col1" >Wheat Seeds Classification</td>
#     </tr>
#     <tr>
#       <th id="T_5368e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5368e_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_5368e_row19_col1" class="data row19 col1" >ded2</td>
#     </tr>
#   </tbody>
# </table>
# Setup complete.
#
# Comparing models...
# <style type="text/css">
# #T_5fe3a th {
#   text-align: left;
# }
# #T_5fe3a_row0_col0, #T_5fe3a_row0_col2, #T_5fe3a_row1_col0, #T_5fe3a_row1_col1, #T_5fe3a_row1_col2, #T_5fe3a_row1_col3, #T_5fe3a_row1_col4, #T_5fe3a_row1_col5, #T_5fe3a_row1_col6, #T_5fe3a_row1_col7, #T_5fe3a_row2_col0, #T_5fe3a_row2_col1, #T_5fe3a_row2_col2, #T_5fe3a_row2_col3, #T_5fe3a_row2_col4, #T_5fe3a_row2_col5, #T_5fe3a_row2_col6, #T_5fe3a_row2_col7, #T_5fe3a_row3_col0, #T_5fe3a_row3_col1, #T_5fe3a_row3_col2, #T_5fe3a_row3_col3, #T_5fe3a_row3_col4, #T_5fe3a_row3_col5, #T_5fe3a_row3_col6, #T_5fe3a_row3_col7, #T_5fe3a_row4_col0, #T_5fe3a_row4_col1, #T_5fe3a_row4_col3, #T_5fe3a_row4_col4, #T_5fe3a_row4_col5, #T_5fe3a_row4_col6, #T_5fe3a_row4_col7, #T_5fe3a_row5_col0, #T_5fe3a_row5_col1, #T_5fe3a_row5_col2, #T_5fe3a_row5_col3, #T_5fe3a_row5_col4, #T_5fe3a_row5_col5, #T_5fe3a_row5_col6, #T_5fe3a_row5_col7, #T_5fe3a_row6_col0, #T_5fe3a_row6_col1, #T_5fe3a_row6_col2, #T_5fe3a_row6_col3, #T_5fe3a_row6_col4, #T_5fe3a_row6_col5, #T_5fe3a_row6_col6, #T_5fe3a_row6_col7, #T_5fe3a_row7_col0, #T_5fe3a_row7_col1, #T_5fe3a_row7_col2, #T_5fe3a_row7_col3, #T_5fe3a_row7_col4, #T_5fe3a_row7_col5, #T_5fe3a_row7_col6, #T_5fe3a_row7_col7, #T_5fe3a_row8_col0, #T_5fe3a_row8_col1, #T_5fe3a_row8_col2, #T_5fe3a_row8_col3, #T_5fe3a_row8_col4, #T_5fe3a_row8_col5, #T_5fe3a_row8_col6, #T_5fe3a_row8_col7, #T_5fe3a_row9_col0, #T_5fe3a_row9_col1, #T_5fe3a_row9_col2, #T_5fe3a_row9_col3, #T_5fe3a_row9_col4, #T_5fe3a_row9_col5, #T_5fe3a_row9_col6, #T_5fe3a_row9_col7, #T_5fe3a_row10_col0, #T_5fe3a_row10_col1, #T_5fe3a_row10_col2, #T_5fe3a_row10_col3, #T_5fe3a_row10_col4, #T_5fe3a_row10_col5, #T_5fe3a_row10_col6, #T_5fe3a_row10_col7, #T_5fe3a_row11_col0, #T_5fe3a_row11_col1, #T_5fe3a_row11_col2, #T_5fe3a_row11_col3, #T_5fe3a_row11_col4, #T_5fe3a_row11_col5, #T_5fe3a_row11_col6, #T_5fe3a_row11_col7, #T_5fe3a_row12_col0, #T_5fe3a_row12_col1, #T_5fe3a_row12_col2, #T_5fe3a_row12_col3, #T_5fe3a_row12_col4, #T_5fe3a_row12_col5, #T_5fe3a_row12_col6, #T_5fe3a_row12_col7, #T_5fe3a_row13_col0, #T_5fe3a_row13_col1, #T_5fe3a_row13_col2, #T_5fe3a_row13_col3, #T_5fe3a_row13_col4, #T_5fe3a_row13_col5, #T_5fe3a_row13_col6, #T_5fe3a_row13_col7, #T_5fe3a_row14_col0, #T_5fe3a_row14_col1, #T_5fe3a_row14_col2, #T_5fe3a_row14_col3, #T_5fe3a_row14_col4, #T_5fe3a_row14_col5, #T_5fe3a_row14_col6, #T_5fe3a_row14_col7, #T_5fe3a_row15_col0, #T_5fe3a_row15_col1, #T_5fe3a_row15_col2, #T_5fe3a_row15_col3, #T_5fe3a_row15_col4, #T_5fe3a_row15_col5, #T_5fe3a_row15_col6, #T_5fe3a_row15_col7 {
#   text-align: left;
# }
# #T_5fe3a_row0_col1, #T_5fe3a_row0_col3, #T_5fe3a_row0_col4, #T_5fe3a_row0_col5, #T_5fe3a_row0_col6, #T_5fe3a_row0_col7, #T_5fe3a_row4_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5fe3a_row0_col8, #T_5fe3a_row1_col8, #T_5fe3a_row2_col8, #T_5fe3a_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_5fe3a_row4_col8, #T_5fe3a_row5_col8, #T_5fe3a_row6_col8, #T_5fe3a_row7_col8, #T_5fe3a_row8_col8, #T_5fe3a_row9_col8, #T_5fe3a_row10_col8, #T_5fe3a_row11_col8, #T_5fe3a_row12_col8, #T_5fe3a_row13_col8, #T_5fe3a_row14_col8, #T_5fe3a_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5fe3a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fe3a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5fe3a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5fe3a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5fe3a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5fe3a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5fe3a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5fe3a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5fe3a_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_5fe3a_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fe3a_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_5fe3a_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_5fe3a_row0_col1" class="data row0 col1" >0.9709</td>
#       <td id="T_5fe3a_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_5fe3a_row0_col3" class="data row0 col3" >0.9709</td>
#       <td id="T_5fe3a_row0_col4" class="data row0 col4" >0.9765</td>
#       <td id="T_5fe3a_row0_col5" class="data row0 col5" >0.9708</td>
#       <td id="T_5fe3a_row0_col6" class="data row0 col6" >0.9564</td>
#       <td id="T_5fe3a_row0_col7" class="data row0 col7" >0.9592</td>
#       <td id="T_5fe3a_row0_col8" class="data row0 col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_5fe3a_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_5fe3a_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_5fe3a_row1_col1" class="data row1 col1" >0.9643</td>
#       <td id="T_5fe3a_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_5fe3a_row1_col3" class="data row1 col3" >0.9643</td>
#       <td id="T_5fe3a_row1_col4" class="data row1 col4" >0.9712</td>
#       <td id="T_5fe3a_row1_col5" class="data row1 col5" >0.9642</td>
#       <td id="T_5fe3a_row1_col6" class="data row1 col6" >0.9465</td>
#       <td id="T_5fe3a_row1_col7" class="data row1 col7" >0.9499</td>
#       <td id="T_5fe3a_row1_col8" class="data row1 col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_5fe3a_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_5fe3a_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_5fe3a_row2_col1" class="data row2 col1" >0.9560</td>
#       <td id="T_5fe3a_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T
level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_86224_row5_col0" class="data row5 col0" >0.8571</td>
#       <td id="T_86224_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_86224_row5_col2" class="data row5 col2" >0.8571</td>
#       <td id="T_86224_row5_col3" class="data row5 col3" >0.8980</td>
#       <td id="T_86224_row5_col4" class="data row5 col4" >0.8512</td>
#       <td id="T_86224_row5_col5" class="data row5 col5" >0.7846</td>
#       <td id="T_86224_row5_col6" class="data row5 col6" >0.8099</td>
#     </tr>
#     <tr>
#       <th id="T_86224_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_86224_row6_col0" class="data row6 col0" >0.8571</td>
#       <td id="T_86224_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_86224_row6_col2" class="data row6 col2" >0.8571</td>
#       <td id="T_86224_row6_col3" class="data row6 col3" >0.8833</td>
#       <td id="T_86224_row6_col4" class="data row6 col4" >0.8465</td>
#       <td id="T_86224_row6_col5" class="data row6 col5" >0.7863</td>
#       <td id="T_86224_row6_col6" class="data row6 col6" >0.8048</td>
#     </tr>
#     <tr>
#       <th id="T_86224_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_86224_row7_col0" class="data row7 col0" >0.8571</td>
#       <td id="T_86224_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_86224_row7_col2" class="data row7 col2" >0.8571</td>
#       <td id="T_86224_row7_col3" class="data row7 col3" >0.8833</td>
#       <td id="T_86224_row7_col4" class="data row7 col4" >0.8465</td>
#       <td id="T_86224_row7_col5" class="data row7 col5" >0.7863</td>
#       <td id="T_86224_row7_col6" class="data row7 col6" >0.8048</td>
#     </tr>
#     <tr>
#       <th id="T_86224_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_86224_row8_col0" class="data row8 col0" >0.9286</td>
#       <td id="T_86224_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_86224_row8_col2" class="data row8 col2" >0.9286</td>
#       <td id="T_86224_row8_col3" class="data row8 col3" >0.9405</td>
#       <td id="T_86224_row8_col4" class="data row8 col4" >0.9267</td>
#       <td id="T_86224_row8_col5" class="data row8 col5" >0.8915</td>
#       <td id="T_86224_row8_col6" class="data row8 col6" >0.8985</td>
#     </tr>
#     <tr>
#       <th id="T_86224_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_86224_row9_col0" class="data row9 col0" >0.8462</td>
#       <td id="T_86224_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_86224_row9_col2" class="data row9 col2" >0.8462</td>
#       <td id="T_86224_row9_col3" class="data row9 col3" >0.8769</td>
#       <td id="T_86224_row9_col4" class="data row9 col4" >0.8355</td>
#       <td id="T_86224_row9_col5" class="data row9 col5" >0.7719</td>
#       <td id="T_86224_row9_col6" class="data row9 col6" >0.7928</td>
#     </tr>
#     <tr>
#       <th id="T_86224_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_86224_row10_col0" class="data row10 col0" >0.9060</td>
#       <td id="T_86224_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_86224_row10_col2" class="data row10 col2" >0.9060</td>
#       <td id="T_86224_row10_col3" class="data row10 col3" >0.9300</td>
#       <td id="T_86224_row10_col4" class="data row10 col4" >0.9026</td>
#       <td id="T_86224_row10_col5" class="data row10 col5" >0.8596</td>
#       <td id="T_86224_row10_col6" class="data row10 col6" >0.8732</td>
#     </tr>
#     <tr>
#       <th id="T_86224_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_86224_row11_col0" class="data row11 col0" >0.0726</td>
#       <td id="T_86224_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_86224_row11_col2" class="data row11 col2" >0.0726</td>
#       <td id="T_86224_row11_col3" class="data row11 col3" >0.0509</td>
#       <td id="T_86224_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# Tuned model: QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)
#
# Evaluating tuned model...
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Finalizing model for deployment...
# Transformation Pipeline and Model Successfully Saved
# Final model saved as 'wheat_seeds.pkl'.
#
#  Experiment finished — all metrics, plots, and models logged automatically to MLflow.
