# %% [markdown]
# # Task 2 — PyCaret Regression Pipeline (Used Car Prices)
#
# We use the **cleaned dataset** produced in Task 1 (`02_Used_Car_Prices_Cleaned.xlsx`).
# Cleaning already done:
# - Standardized column names and **renamed target** to `Price`
# - Extracted numerics from `Mileage`, `Engine`, `Power` (removed units like *kmpl*, *CC*, *bhp*)
# - Cast `Seats`, `Year`, `Kilometers_Driven` to numeric
# - Normalized `Location` (strip + title case), cast all categoricals
# - Added `Brand` from `Brand_Model`
# - Median imputation for numeric, mode imputation for categoricals
# - Saved as `data/02_Used_Car_Prices_Cleaned.xlsx`
#
# Now, we’ll:
# 1) Engineer a few helpful features (e.g., **Age**),
# 2) Initialize **PyCaret** with strong preprocessing,
# 3) Compare, **tune**, and **ensemble** top models via 5-fold CV,
# 4) Evaluate on hold-out + unseen,
# 5) **Save the full pipeline** for Task 3, and
# 6) Ensure **MLflow** logging is enabled (as required).

# %%
import warnings; warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from datetime import datetime

# PyCaret - regression
from pycaret.regression import *

from pathlib import Path
import json, numpy as np, mlflow
import os, mlflow

# %% [markdown]
# ## Load cleaned dataset + confirmation

# %%
# Load the cleaned file from Task 1
df = pd.read_excel("../data/02_Used_Car_Prices_Cleaned.xlsx")

print("Shape:", df.shape)
display(df.head())

# Quick type check (should already be clean)
df.info()
# Out:
# Shape: (6019, 13)
#                         Brand_Model    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60     998   58.16      5
# 1    Diesel       Manual      First    19.67    1582  126.20      5
# 2    Petrol       Manual      First    18.20    1199   88.70      5
# 3    Diesel       Manual      First    20.77    1248   88.76      7
# 4    Diesel    Automatic     Second    15.20    1968  140.80      5
#
#        Price    Brand
# 0   175000.0   Maruti
# 1  1250000.0  Hyundai
# 2   450000.0    Honda
# 3   600000.0   Maruti
# 4  1774000.0     Audi
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand_Model        6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6019 non-null   float64
#  8   Engine             6019 non-null   int64
#  9   Power              6019 non-null   float64
#  10  Seats              6019 non-null   int64
#  11  Price              6019 non-null   float64
#  12  Brand              6019 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 611.4+ KB

# %% [markdown]
# ## Extra feature engineering

# %%
# Age of car = current year - Year (floor at 0)
this_year = datetime.now().year
df["Age"] = (this_year - df["Year"]).clip(lower=0)

# Optional: log transform helper column for km (kept as numeric feature)
df["Log_Km"] = np.log1p(df["Kilometers_Driven"])

# (Optional) target sanity check
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
df = df.dropna(subset=["Price"]).reset_index(drop=True)

df[["Price","Year","Age","Kilometers_Driven","Log_Km","Mileage","Engine","Power","Seats"]].describe()
# Out:
#               Price         Year          Age  Kilometers_Driven       Log_Km  \
# count  6.019000e+03  6019.000000  6019.000000       6.019000e+03  6019.000000
# mean   9.479468e+05  2013.358199    11.641801       5.873838e+04    10.758812
# std    1.118792e+06     3.269742     3.269742       9.126884e+04     0.715736
# min    4.400000e+04  1998.000000     6.000000       1.710000e+02     5.147494
# 25%    3.500000e+05  2011.000000     9.000000       3.400000e+04    10.434145
# 50%    5.640000e+05  2014.000000    11.000000       5.300000e+04    10.878066
# 75%    9.950000e+05  2016.000000    14.000000       7.300000e+04    11.198228
# max    1.600000e+07  2019.000000    27.000000       6.500000e+06    15.687313
#
#            Mileage       Engine        Power        Seats
# count  6019.000000  6019.000000  6019.000000  6019.000000
# mean     18.134966  1620.509221   112.883539     5.276790
# std       4.581528   599.635458    53.283701     0.806346
# min       0.000000    72.000000    34.200000     0.000000
# 25%      15.170000  1198.000000    78.000000     5.000000
# 50%      18.150000  1493.000000    97.700000     5.000000
# 75%      21.100000  1969.000000   138.030000     5.000000
# max      33.540000  5998.000000   560.000000    10.000000

# %% [markdown]
# # MLflow
# - Data: `../data/02_Used_Car_Prices_Cleaned.xlsx` (from Task 1)
# - We’ll engineer `Age` & `Log_Km`, build a PyCaret regression pipeline,
#   compare/tune/ensemble models, and log artifacts/metrics to MLflow **manually**
#   (works with MLflow 3.x).
# - Experiment name: **usedcar_prices**

# %%
# Reproducibility
np.random.seed(42)

# %% [markdown]
# ## MLflow tracking (local folder)

# %%
# Use a project-local mlruns folder
project_root = Path.cwd().resolve()
tracking_dir = (project_root / "../mlruns").resolve()
tracking_dir.mkdir(parents=True, exist_ok=True)

mlflow_uri = tracking_dir.as_uri()     # file:///C:/.../mlruns (Windows-safe)
os.environ["MLFLOW_TRACKING_URI"] = mlflow_uri
mlflow.set_tracking_uri(mlflow_uri)

EXP_NAME = "usedcar_prices"
if mlflow.get_experiment_by_name(EXP_NAME) is None:
    mlflow.create_experiment(EXP_NAME)
mlflow.set_experiment(EXP_NAME)

print("Tracking URI:", mlflow.get_tracking_uri())
print("Experiment:", EXP_NAME)
# Out:
# Tracking URI: file:///C:/Users/keaga_0idqj9o/OneDrive/Desktop/School/Y3T2/MLOps/Assignment/usedcar_project/mlruns
# Experiment: usedcar_prices

# %% [markdown]
# ## Pycaret setup (no internal MLflow)

# %%
numeric_features = [
    "Year","Age","Kilometers_Driven","Log_Km",
    "Mileage","Engine","Power","Seats"
]
categorical_features = [
    "Fuel_Type","Transmission","Owner_Type",
    "Location","Brand_Model","Brand"
]

reg_exp = setup(
    data=df,
    target="Price",
    session_id=42,
    train_size=0.8,
    fold=10,
    fold_shuffle=True,

    # 1) Robust preprocessing for skew/outliers
    normalize=True,
    normalize_method="robust",
    transformation=True,                 # transform X (not y)
    transformation_method="quantile",

    # 2) Outliers & multicollinearity
    remove_outliers=True,
    outliers_method="iforest",
    outliers_threshold=0.02,             # top/bottom ~2%
    remove_multicollinearity=True,
    multicollinearity_threshold=0.90,

    # 3) Feature selection (model-based)
    feature_selection=True,
    feature_selection_method="classic",
    feature_selection_estimator="lightgbm",
    n_features_to_select=0.6,            # keep ~60% best features

    # 4) Encoding controls
    max_encoding_ohe=50,                 # cap OHE width
    rare_to_value=0.01,                  # merge levels <1% freq
    rare_value="Other",

    # 5) Helpful binning for non-linearities
    bin_numeric_features=["Age", "Kilometers_Driven"],

    # 6) Imputation (explicit)
    numeric_imputation="median",
    categorical_imputation="mode",

    # 7) Lock schema
    numeric_features=numeric_features,
    categorical_features=categorical_features,

    # We log to MLflow manually (avoid PyCaret↔MLflow conflict)
    log_experiment=False,
    verbose=True,
)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 950
# [LightGBM] [Info] Number of data points in the train set: 4718, number of used features: 42
# [LightGBM] [Info] Start training from score 940764.518864
# <style type="text/css">
# #T_962a8_row9_col1, #T_962a8_row15_col1, #T_962a8_row17_col1, #T_962a8_row19_col1, #T_962a8_row21_col1, #T_962a8_row23_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_962a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_962a8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_962a8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_962a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_962a8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_962a8_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_962a8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_962a8_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_962a8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_962a8_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_962a8_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_962a8_row3_col1" class="data row3 col1" >(6019, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_962a8_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_962a8_row4_col1" class="data row4 col1" >(5922, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_962a8_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_962a8_row5_col1" class="data row5 col1" >(4718, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_962a8_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_962a8_row6_col1" class="data row6 col1" >(1204, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_962a8_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_962a8_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_962a8_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_962a8_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_962a8_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_962a8_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_962a8_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_962a8_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_962a8_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_962a8_row11_col1" class="data row11 col1" >median</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_962a8_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_962a8_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_962a8_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_962a8_row13_col1" class="data row13 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_962a8_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_962a8_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_962a8_row15_col0" class="data row15 col0" >Remove multicollinearity</td>
#       <td id="T_962a8_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_962a8_row16_col0" class="data row16 col0" >Multicollinearity threshold</td>
#       <td id="T_962a8_row16_col1" class="data row16 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_962a8_row17_col0" class="data row17 col0" >Remove outliers</td>
#       <td id="T_962a8_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_962a8_row18_col0" class="data row18 col0" >Outliers threshold</td>
#       <td id="T_962a8_row18_col1" class="data row18 col1" >0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_962a8_row19_col0" class="data row19 col0" >Transformation</td>
#       <td id="T_962a8_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_962a8_row20_col0" class="data row20 col0" >Transformation method</td>
#       <td id="T_962a8_row20_col1" class="data row20 col1" >quantile</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_962a8_row21_col0" class="data row21 col0" >Normalize</td>
#       <td id="T_962a8_row21_col1" class="data row21 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_962a8_row22_col0" class="data row22 col0" >Normalize method</td>
#       <td id="T_962a8_row22_col1" class="data row22 col1" >robust</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_962a8_row23_col0" class="data row23 col0" >Feature selection</td>
#       <td id="T_962a8_row23_col1" class="data row23 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_962a8_row24_col0" class="data row24 col0" >Feature selection method</td>
#       <td id="T_962a8_row24_col1" class="data row24 col1" >classic</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_962a8_row25_col0" class="data row25 col0" >Feature selection estimator</td>
#       <td id="T_962a8_row25_col1" class="data row25 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_962a8_row26_col0" class="data row26 col0" >Number of features selected</td>
#       <td id="T_962a8_row26_col1" class="data row26 col1" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_962a8_row27_col0" class="data row27 col0" >Fold Generator</td>
#       <td id="T_962a8_row27_col1" class="data row27 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_962a8_row28_col0" class="data row28 col0" >Fold Number</td>
#       <td id="T_962a8_row28_col1" class="data row28 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_962a8_row29_col0" class="data row29 col0" >CPU Jobs</td>
#       <td id="T_962a8_row29_col1" class="data row29 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_962a8_level0_row30" class="row_heading level0 row30" >30</th>

# %% [markdown]
# - Uses robust scaling + quantile transforms on features (good for skewed Price drivers).
# - IForest outlier removal at 2% to trim only the worst tails.
# - Multicollinearity cut at 0.90 (safer than 0.95 for Engine/Power/Log_Km).
# - Model-based feature selection with LightGBM; caps features at 60%.
# - Binning Age and Kilometers_Driven adds stepwise effects that tree models exploit.
# - Rare category merging prevents exploding dummies for huge Brand_Model/Location.

# %% [markdown]
# ## Compare Models

# %%
top_models = compare_models(n_select=5, sort="R2")
leaderboard_compare = pull()
leaderboard_compare
# Out:
# <style type="text/css">
# #T_fec54 th {
#   text-align: left;
# }
# #T_fec54_row0_col0, #T_fec54_row0_col5, #T_fec54_row1_col0, #T_fec54_row1_col1, #T_fec54_row1_col2, #T_fec54_row1_col3, #T_fec54_row1_col4, #T_fec54_row1_col5, #T_fec54_row1_col6, #T_fec54_row2_col0, #T_fec54_row2_col1, #T_fec54_row2_col2, #T_fec54_row2_col3, #T_fec54_row2_col4, #T_fec54_row2_col5, #T_fec54_row2_col6, #T_fec54_row3_col0, #T_fec54_row3_col1, #T_fec54_row3_col2, #T_fec54_row3_col3, #T_fec54_row3_col4, #T_fec54_row3_col5, #T_fec54_row3_col6, #T_fec54_row4_col0, #T_fec54_row4_col1, #T_fec54_row4_col2, #T_fec54_row4_col3, #T_fec54_row4_col4, #T_fec54_row4_col6, #T_fec54_row5_col0, #T_fec54_row5_col1, #T_fec54_row5_col2, #T_fec54_row5_col3, #T_fec54_row5_col4, #T_fec54_row5_col5, #T_fec54_row5_col6, #T_fec54_row6_col0, #T_fec54_row6_col1, #T_fec54_row6_col2, #T_fec54_row6_col3, #T_fec54_row6_col4, #T_fec54_row6_col5, #T_fec54_row6_col6, #T_fec54_row7_col0, #T_fec54_row7_col1, #T_fec54_row7_col2, #T_fec54_row7_col3, #T_fec54_row7_col4, #T_fec54_row7_col5, #T_fec54_row7_col6, #T_fec54_row8_col0, #T_fec54_row8_col1, #T_fec54_row8_col2, #T_fec54_row8_col3, #T_fec54_row8_col4, #T_fec54_row8_col5, #T_fec54_row8_col6, #T_fec54_row9_col0, #T_fec54_row9_col1, #T_fec54_row9_col2, #T_fec54_row9_col3, #T_fec54_row9_col4, #T_fec54_row9_col5, #T_fec54_row9_col6, #T_fec54_row10_col0, #T_fec54_row10_col1, #T_fec54_row10_col2, #T_fec54_row10_col3, #T_fec54_row10_col4, #T_fec54_row10_col5, #T_fec54_row10_col6, #T_fec54_row11_col0, #T_fec54_row11_col1, #T_fec54_row11_col2, #T_fec54_row11_col3, #T_fec54_row11_col4, #T_fec54_row11_col5, #T_fec54_row11_col6, #T_fec54_row12_col0, #T_fec54_row12_col1, #T_fec54_row12_col2, #T_fec54_row12_col3, #T_fec54_row12_col4, #T_fec54_row12_col5, #T_fec54_row12_col6, #T_fec54_row13_col0, #T_fec54_row13_col1, #T_fec54_row13_col2, #T_fec54_row13_col3, #T_fec54_row13_col4, #T_fec54_row13_col5, #T_fec54_row13_col6, #T_fec54_row14_col0, #T_fec54_row14_col1, #T_fec54_row14_col2, #T_fec54_row14_col3, #T_fec54_row14_col4, #T_fec54_row14_col5, #T_fec54_row14_col6, #T_fec54_row15_col0, #T_fec54_row15_col1, #T_fec54_row15_col2, #T_fec54_row15_col3, #T_fec54_row15_col4, #T_fec54_row15_col5, #T_fec54_row15_col6, #T_fec54_row16_col0, #T_fec54_row16_col1, #T_fec54_row16_col2, #T_fec54_row16_col3, #T_fec54_row16_col4, #T_fec54_row16_col5, #T_fec54_row16_col6, #T_fec54_row17_col0, #T_fec54_row17_col1, #T_fec54_row17_col2, #T_fec54_row17_col3, #T_fec54_row17_col4, #T_fec54_row17_col5, #T_fec54_row17_col6, #T_fec54_row18_col0, #T_fec54_row18_col1, #T_fec54_row18_col2, #T_fec54_row18_col3, #T_fec54_row18_col4, #T_fec54_row18_col5, #T_fec54_row18_col6, #T_fec54_row19_col0, #T_fec54_row19_col1, #T_fec54_row19_col2, #T_fec54_row19_col3, #T_fec54_row19_col4, #T_fec54_row19_col5, #T_fec54_row19_col6 {
#   text-align: left;
# }
# #T_fec54_row0_col1, #T_fec54_row0_col2, #T_fec54_row0_col3, #T_fec54_row0_col4, #T_fec54_row0_col6, #T_fec54_row4_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fec54_row0_col7, #T_fec54_row1_col7, #T_fec54_row2_col7, #T_fec54_row3_col7, #T_fec54_row4_col7, #T_fec54_row5_col7, #T_fec54_row6_col7, #T_fec54_row7_col7, #T_fec54_row8_col7, #T_fec54_row9_col7, #T_fec54_row10_col7, #T_fec54_row11_col7, #T_fec54_row12_col7, #T_fec54_row13_col7, #T_fec54_row14_col7, #T_fec54_row15_col7, #T_fec54_row16_col7, #T_fec54_row17_col7, #T_fec54_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fec54_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fec54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fec54_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fec54_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fec54_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fec54_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fec54_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fec54_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fec54_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fec54_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fec54_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_fec54_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_fec54_row0_col1" class="data row0 col1" >153922.0448</td>
#       <td id="T_fec54_row0_col2" class="data row0 col2" >129602150192.8826</td>
#       <td id="T_fec54_row0_col3" class="data row0 col3" >343869.0760</td>
#       <td id="T_fec54_row0_col4" class="data row0 col4" >0.9022</td>
#       <td id="T_fec54_row0_col5" class="data row0 col5" >0.2542</td>
#       <td id="T_fec54_row0_col6" class="data row0 col6" >0.1967</td>
#       <td id="T_fec54_row0_col7" class="data row0 col7" >0.7580</td>
#     </tr>
#     <tr>
#       <th id="T_fec54_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_fec54_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_fec54_row1_col1" class="data row1 col1" >156893.4031</td>
#       <td id="T_fec54_row1_col2" class="data row1 col2" >140751117516.8000</td>
#       <td id="T_fec54_row1_col3" class="data row1 col3" >360050.4406</td>
#       <td id="T_fec54_row1_col4" class="data row1 col4" >0.8932</td>
#       <td id="T_fec54_row1_col5" class="data row1 col5" >0.2608</td>
#       <td id="T_fec54_row1_col6" class="data row1 col6" >0.1999</td>
#       <td id="T_fec54_row1_col7" class="data row1 col7" >0.2490</td>
#     </tr>
#     <tr>
#       <th id="T_fec54_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_fec54_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_fec54_row2_col1" class="data row2 col1" >162653.6012</td>
#       <td id="T_fec54_row2_col2" class="data row2 col2" >139448973222.7112</td>
#       <td id="T_fec54_row2_col3" class="data row2 col3" >360547.7546</td>
#       <td id="T_fec54_row2_col4" class="data row2 col4" >0.8932</td>
#       <td id="T_fec54_row2_col5" class="data row2 col5" >0.2720</td>
#       <td id="T_fec54_row2_col6" class="data row2 col6" >0.2034</td>
#       <td id="T_fec54_row2_col7" class="data row2 col7" >0.2710</td>
#     </tr>
#     <tr>
#       <th id="T_fec54_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_fec54_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_fec54_row3_col1" class="data row3 col1" >161997.1870</td>
#       <td id="T_fec54_row3_col2" class="data row3 col2" >144667446008.3153</td>
#       <td id="T_fec54_row3_col3" class="data row3 col3" >364541.1528</td>
#       <td id="T_fec54_row3_col4" class="data row3 col4" >0.8905</td>
#       <td id="T_fec54_row3_col5" class="data row3 col5" >0.2555</td>
#       <td id="T_fec54_row3_col6" class="data row3 col6" >0.2042</td>
#       <td id="T_fec54_row3_col7" class="data row3 col7" >0.2750</td>
#     </tr>
#     <tr>
#       <th id="T_fec54_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_fec54_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_fec54_row4_col1" class="data row4 col1" >160659.3745</td>
#       <td id="T_fec54_row4_col2" class="data row4 col2" >144907284522.9275</td>
#       <td id="T_fec54_row4_col3" class="data row4 col3" >366650.5263</td>
#       <td id="T_fec54_row4_col4" class="data row4 col4" >0.8896</td>
#       <td id="T_fec54_row4_col5" class="data row4 col5" >0.2532</td>
#       <td id="T_fec54_row4_col6" class="data row4 col6" >0.2004</td>
#       <td id="T_fec54_row4_col7" class="data row4 col7" >0.3180</td>
#     </tr>
#     <tr>
#       <th id="T_fec54_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_fec54_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_fec54_row5_col1" class="data row5 col1" >185636.2605</td>
#                                     Model          MAE           MSE  \
# catboost               CatBoost Regressor  153922.0448  1.296022e+11
# xgboost         Extreme Gradient Boosting  156893.4031  1.407511e+11
# lightgbm  Light Gradient Boosting Machine  162653.6012  1.394490e+11
# et                  Extra Trees Regressor  161997.1870  1.446674e+11
# rf                Random Forest Regressor  160659.3745  1.449073e+11
# gbr           Gradient Boosting Regressor  185636.2605  1.513807e+11
# knn                 K Neighbors Regressor  204706.1422  2.114358e+11
# dt                Decision Tree Regressor  202847.2071  2.522395e+11
# ada                    AdaBoost Regressor  546613.0085  4.610772e+11
# ridge                    Ridge Regression  428383.2267  4.872543e+11
# lasso                    Lasso Regression  428395.9972  4.872520e+11
# lar                Least Angle Regression  428396.4125  4.872518e+11
# llar         Lasso Least Angle Regression  428396.0006  4.872520e+11
# br                         Bayesian Ridge  428335.5072  4.872655e+11
# lr                      Linear Regression  428396.4125  4.872518e+11
# en                            Elastic Net  426445.1613  5.728037e+11
# huber                     Huber Regressor  379810.6148  5.948414e+11
# par          Passive Aggressive Regressor  381921.2464  6.420234e+11
# omp           Orthogonal Matching Pursuit  626484.2286  1.002962e+12
# dummy                     Dummy Regressor  711703.6375  1.257461e+12
#
#                   RMSE      R2   RMSLE    MAPE  TT (Sec)
# catboost  3.438691e+05  0.9022  0.2542  0.1967     0.758
# xgboost   3.600504e+05  0.8932  0.2608  0.1999     0.249
# lightgbm  3.605478e+05  0.8932  0.2720  0.2034     0.271
# et        3.645412e+05  0.8905  0.2555  0.2042     0.275
# rf        3.666505e+05  0.8896  0.2532  0.2004     0.318
# gbr       3.794676e+05  0.8826  0.2894  0.2391     0.252
# knn       4.493643e+05  0.8371  0.2962  0.2442     0.205
# dt        4.920849e+05  0.7991  0.3223  0.2526     0.197
# ada       6.698909e+05  0.6313  0.8779  1.3784     0.234
# ridge     6.928514e+05  0.6151  0.8139  0.8209     0.199
# lasso     6.928511e+05  0.6151  0.8169  0.8210     0.394
# lar       6.928510e+05  0.6151  0.8169  0.8210     0.201
# llar      6.928511e+05  0.6151  0.8168  0.8210     0.197
# br        6.928546e+05  0.6151  0.8146  0.8206     0.189
# lr        6.928510e+05  0.6151  0.8169  0.8210     0.615
# en        7.507175e+05  0.5491  0.6721  0.6948     0.196
# huber     7.646382e+05  0.5325  0.6133  0.5190     0.197
# par       7.948668e+05  0.4947  0.6119  0.4876     0.233
# omp       9.890333e+05  0.2105  0.9196  1.2156     0.187
# dummy     1.116852e+06 -0.0026  0.9659  1.3780     0.194

# %% [markdown]
# ### Model Comparison Insights
#
# From the model leaderboard, we can draw several key observations:
#
# 1. **Top Performing Models**
#    - **CatBoost Regressor** achieved the **best performance** with
#      - **R² = 0.90** (explains ~90% of the variance in car prices)
#      - **MAE ≈ 154k INR**, meaning on average the model’s predictions are within ±1.5 lakhs of the actual selling price.
#    - **XGBoost** and **LightGBM** follow closely with R² around **0.89**, also providing strong generalization.
#    - These gradient-boosting tree ensembles are well-suited for tabular data with mixed numeric and categorical features.
#
# 2. **Strong Baseline Models**
#    - **Extra Trees** and **Random Forest** also perform competitively (R² ≈ 0.89), showing that tree ensembles in general capture the key price-driving patterns.
#    - **Gradient Boosting Regressor (sklearn)** lags slightly (R² ≈ 0.88), but still provides a good baseline.
#
# 3. **Weaker / Linear Models**
#    - Linear-based models (Ridge, Lasso, Elastic Net, Bayesian Ridge, Linear Regression) plateau around **R² = 0.61**, confirming that **used car pricing is highly non-linear** and cannot be captured well with simple linear assumptions.
#    - These models also show much higher MAE (> 400k INR), making them less reliable.
#
# 4. **Poor Performers**
#    - **AdaBoost, Huber, Passive Aggressive, OMP** and the **Dummy baseline** all perform significantly worse, with R² < 0.65. These models are unsuitable for the task.
#
# 5. **Interpretation**
#    - The best models (CatBoost, XGBoost, LightGBM) are tree-based ensemble learners that:
#      - Handle complex interactions between features (e.g., brand × engine power × location).
#      - Are robust to outliers and non-linear relationships.
#      - Natively support categorical variables (especially CatBoost).
#
# ---
# **Conclusion**: CatBoost is the current champion and will likely be selected as the final model. However, XGBoost and LightGBM remain strong contenders and should be considered for blending or stacking in the final pipeline.

# %% [markdown]
# ## Tuning the top models

# %%
tuned_models = [tune_model(m, optimize="R2") for m in top_models]
leaderboard_tune = pull()
leaderboard_tune
# Out:
# <style type="text/css">
# #T_c4697_row10_col0, #T_c4697_row10_col1, #T_c4697_row10_col2, #T_c4697_row10_col3, #T_c4697_row10_col4, #T_c4697_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c4697">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4697_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c4697_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c4697_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c4697_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c4697_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c4697_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4697_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c4697_row0_col0" class="data row0 col0" >187981.3470</td>
#       <td id="T_c4697_row0_col1" class="data row0 col1" >122386002152.6833</td>
#       <td id="T_c4697_row0_col2" class="data row0 col2" >349837.1080</td>
#       <td id="T_c4697_row0_col3" class="data row0 col3" >0.8938</td>
#       <td id="T_c4697_row0_col4" class="data row0 col4" >0.3108</td>
#       <td id="T_c4697_row0_col5" class="data row0 col5" >0.2552</td>
#     </tr>
#     <tr>
#       <th id="T_c4697_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c4697_row1_col0" class="data row1 col0" >198324.0789</td>
#       <td id="T_c4697_row1_col1" class="data row1 col1" >235505352852.6586</td>
#       <td id="T_c4697_row1_col2" class="data row1 col2" >485288.9375</td>
#       <td id="T_c4697_row1_col3" class="data row1 col3" >0.8401</td>
#       <td id="T_c4697_row1_col4" class="data row1 col4" >0.2869</td>
#       <td id="T_c4697_row1_col5" class="data row1 col5" >0.2238</td>
#     </tr>
#     <tr>
#       <th id="T_c4697_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c4697_row2_col0" class="data row2 col0" >194882.3836</td>
#       <td id="T_c4697_row2_col1" class="data row2 col1" >109834600725.6721</td>
#       <td id="T_c4697_row2_col2" class="data row2 col2" >331413.0364</td>
#       <td id="T_c4697_row2_col3" class="data row2 col3" >0.9208</td>
#       <td id="T_c4697_row2_col4" class="data row2 col4" >0.3030</td>
#       <td id="T_c4697_row2_col5" class="data row2 col5" >0.2428</td>
#     </tr>
#     <tr>
#       <th id="T_c4697_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c4697_row3_col0" class="data row3 col0" >199803.6119</td>
#       <td id="T_c4697_row3_col1" class="data row3 col1" >138585574456.7012</td>
#       <td id="T_c4697_row3_col2" class="data row3 col2" >372270.8348</td>
#       <td id="T_c4697_row3_col3" class="data row3 col3" >0.8448</td>
#       <td id="T_c4697_row3_col4" class="data row3 col4" >0.4150</td>
#       <td id="T_c4697_row3_col5" class="data row3 col5" >0.2679</td>
#     </tr>
#     <tr>
#       <th id="T_c4697_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c4697_row4_col0" class="data row4 col0" >179223.6075</td>
#       <td id="T_c4697_row4_col1" class="data row4 col1" >98024871439.4442</td>
#       <td id="T_c4697_row4_col2" class="data row4 col2" >313089.2388</td>
#       <td id="T_c4697_row4_col3" class="data row4 col3" >0.9288</td>
#       <td id="T_c4697_row4_col4" class="data row4 col4" >0.2889</td>
#       <td id="T_c4697_row4_col5" class="data row4 col5" >0.2349</td>
#     </tr>
#     <tr>
#       <th id="T_c4697_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c4697_row5_col0" class="data row5 col0" >186429.5551</td>
#       <td id="T_c4697_row5_col1" class="data row5 col1" >110697849556.3288</td>
#       <td id="T_c4697_row5_col2" class="data row5 col2" >332712.8635</td>
#       <td id="T_c4697_row5_col3" class="data row5 col3" >0.8967</td>
#       <td id="T_c4697_row5_col4" class="data row5 col4" >0.3363</td>
#       <td id="T_c4697_row5_col5" class="data row5 col5" >0.2621</td>
#     </tr>
#     <tr>
#       <th id="T_c4697_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c4697_row6_col0" class="data row6 col0" >198553.0226</td>
#       <td id="T_c4697_row6_col1" class="data row6 col1" >323072675425.5200</td>
#       <td id="T_c4697_row6_col2" class="data row6 col2" >568394.8235</td>
#       <td id="T_c4697_row6_col3" class="data row6 col3" >0.8063</td>
#       <td id="T_c4697_row6_col4" class="data row6 col4" >0.3361</td>
#       <td id="T_c4697_row6_col5" class="data row6 col5" >0.2668</td>
#     </tr>
#     <tr>
#       <th id="T_c4697_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c4697_row7_col0" class="data row7 col0" >207833.2433</td>
#       <td id="T_c4697_row7_col1" class="data row7 col1" >185195512352.9718</td>
#       <td id="T_c4697_row7_col2" class="data row7 col2" >430343.4818</td>
#       <td id="T_c4697_row7_col3" class="data row7 col3" >0.8546</td>
#       <td id="T_c4697_row7_col4" class="data row7 col4" >0.3811</td>
#       <td id="T_c4697_row7_col5" class="data row7 col5" >0.2616</td>
#     </tr>
#     <tr>
#       <th id="T_c4697_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c4697_row8_col0" class="data row8 col0" >186639.8431</td>
#       <td id="T_c4697_row8_col1" class="data row8 col1" >138770995308.8971</td>
#       <td id="T_c4697_row8_col2" class="data row8 col2" >372519.7918</td>
#       <td id="T_c4697_row8_col3" class="data row8 col3" >0.8574</td>
#       <td id="T_c4697_row8_col4" class="data row8 col4" >0.3273</td>
#       <td id="T_c4697_row8_col5" class="data row8 col5" >0.2594</td>
#     </tr>
#     <tr>
#       <th id="T_c4697_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c4697_row9_col0" class="data row9 col0" >197565.4206</td>
#       <td id="T_c4697_row9_col1" class="data row9 col1" >104707726447.1791</td>
#       <td id="T_c4697_row9_col2" class="data row9 col2" >323585.7328</td>
#       <td id="T_c4697_row9_col3" class="data row9 col3" >0.9179</td>
#       <td id="T_c4697_row9_col4" class="data row9 col4" >0.3654</td>
#       <td id="T_c4697_row9_col5" class="data row9 col5" >0.2676</td>
#     </tr>
#     <tr>
#       <th id="T_c4697_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c4697_row10_col0" class="data row10 col0" >193723.6114</td>
#       <td id="T_c4697_row10_col1" class="data row10 col1" >156678116071.8056</td>
#       <td id="T_c4697_row10_col2" class="data row10 col2" >387945.5849</td>
#       <td id="T_c4697_row10_col3" class="data row10 col3" >0.8761</td>
#       <td id="T_c4697_row10_col4" class="data row10 col4" >0.3351</td>
#       <td id="T_c4697_row10_col5" class="data row10 col5" >0.2542</td>
#     </tr>
#     <tr>
#       <th id="T_c4697_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c4697_row11_col0" class="data row11 col0" >8020.2533</td>
#       <td id="T_c4697_row11_col1" class="data row11 col1" >68547576899.0335</td>
#       <td id="T_c4697_row11_col2" class="data row11 col2" >78589.6890</td>
#       <td id="T_c4697_row11_col3" class="data row11 col3" >0.0390</td>
#       <td id="T_c4697_row11_col4" class="data row11 col4" >0.0394</td>
#       <td id="T_c4697_row11_col5" class="data row11 col5" >0.0145</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_91d35_row10_col0, #T_91d35_row10_col1, #T_91d35_row10_col2, #T_91d35_row10_col3, #T_91d35_row10_col4, #T_91d35_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_91d35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91d35_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_91d35_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_91d35_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_91d35_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_91d35_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_91d35_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91d35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_91d35_row0_col0" class="data row0 col0" >156920.5312</td>
#       <td id="T_91d35_row0_col1" class="data row0 col1" >87108452352.0000</td>
#       <td id="T_91d35_row0_col2" class="data row0 col2" >295141.4062</td>
#       <td id="T_91d35_row0_col3" class="data row0 col3" >0.9244</td>
#       <td id="T_91d35_row0_col4" class="data row0 col4" >0.2569</td>
#       <td id="T_91d35_row0_col5" class="data row0 col5" >0.2052</td>
#     </tr>
#     <tr>
#       <th id="T_91d35_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_91d35_row1_col0" class="data row1 col0" >172217.5312</td>
#       <td id="T_91d35_row1_col1" class="data row1 col1" >254284627968.0000</td>
#       <td id="T_91d35_row1_col2" class="data row1 col2" >504266.4375</td>
#       <td id="T_91d35_row1_col3" class="data row1 col3" >0.8273</td>
#       <td id="T_91d35_row1_col4" class="data row1 col4" >0.2334</td>
#       <td id="T_91d35_row1_col5" class="data row1 col5" >0.1790</td>
#     </tr>
#     <tr>
#       <th id="T_91d35_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_91d35_row2_col0" class="data row2 col0" >185673.4062</td>
#       <td id="T_91d35_row2_col1" class="data row2 col1" >119069851648.0000</td>
#       <td id="T_91d35_row2_col2" class="data row2 col2" >345065.0000</td>
#       <td id="T_91d35_row2_col3" class="data row2 col3" >0.9142</td>
#       <td id="T_91d35_row2_col4" class="data row2 col4" >0.2783</td>
#       <td id="T_91d35_row2_col5" class="data row2 col5" >0.2287</td>
#     </tr>
#     <tr>
#       <th id="T_91d35_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_91d35_row3_col0" class="data row3 col0" >157690.2500</td>
#       <td id="T_91d35_row3_col1" class="data row3 col1" >91052736512.0000</td>
#       <td id="T_91d35_row3_col2" class="data row3 col2" >301749.4688</td>
#       <td id="T_91d35_row3_col3" class="data row3 col3" >0.8980</td>
#       <td id="T_91d35_row3_col4" class="data row3 col4" >0.2626</td>
#       <td id="T_91d35_row3_col5" class="data row3 col5" >0.2136</td>
#     </tr>
#     <tr>
#       <th id="T_91d35_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_91d35_row4_col0" class="data row4 col0" >152331.4844</td>
#       <td id="T_91d35_row4_col1" class="data row4 col1" >95415402496.0000</td>
#       <td id="T_91d35_row4_col2" class="data row4 col2" >308893.8438</td>
#       <td id="T_91d35_row4_col3" class="data row4 col3" >0.9307</td>
#       <td id="T_91d35_row4_col4" class="data row4 col4" >0.2470</td>
#       <td id="T_91d35_row4_col5" class="data row4 col5" >0.1966</td>
#     </tr>
#     <tr>
#       <th id="T_91d35_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_91d35_row5_col0" class="data row5 col0" >154037.3281</td>
#       <td id="T_91d35_row5_col1" class="data row5 col1" >92287188992.0000</td>
#       <td id="T_91d35_row5_col2" class="data row5 col2" >303788.0625</td>
#       <td id="T_91d35_row5_col3" class="data row5 col3" >0.9139</td>
#       <td id="T_91d35_row5_col4" class="data row5 col4" >0.2564</td>
#       <td id="T_91d35_row5_col5" class="data row5 col5" >0.1946</td>
#     </tr>
#     <tr>
#       <th id="T_91d35_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_91d35_row6_col0" class="data row6 col0" >173632.9531</td>
#       <td id="T_91d35_row6_col1" class="data row6 col1" >329153085440.0000</td>
#       <td id="T_91d35_row6_col2" class="data row6 col2" >573718.6250</td>
#       <td id="T_91d35_row6_col3" class="data row6 col3" >0.8027</td>
#       <td id="T_91d35_row6_col4" class="data row6 col4" >0.2673</td>
#       <td id="T_91d35_row6_col5" class="data row6 col5" >0.2116</td>
#     </tr>
#     <tr>
#       <th id="T_91d35_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_91d35_row7_col0" class="data row7 col0" >175320.3125</td>
#       <td id="T_91d35_row7_col1" class="data row7 col1" >117970796544.0000</td>
#       <td id="T_91d35_row7_col2" class="data row7 col2" >343468.7812</td>
#       <td id="T_91d35_row7_col3" class="data row7 col3" >0.9074</td>
#       <td id="T_91d35_row7_col4" class="data row7 col4" >0.2554</td>
#       <td id="T_91d35_row7_col5" class="data row7 col5" >0.2099</td>
#     </tr>
#     <tr>
#       <th id="T_91d35_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_91d35_row8_col0" class="data row8 col0" >149012.7344</td>
#       <td id="T_91d35_row8_col1" class="data row8 col1" >71807451136.0000</td>
#       <td id="T_91d35_row8_col2" class="data row8 col2" >267969.1250</td>
#       <td id="T_91d35_row8_col3" class="data row8 col3" >0.9262</td>
#       <td id="T_91d35_row8_col4" class="data row8 col4" >0.2667</td>
#       <td id="T_91d35_row8_col5" class="data row8 col5" >0.2178</td>
#     </tr>
#     <tr>
#       <th id="T_91d35_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_91d35_row9_col0" class="data row9 col0" >165293.2344</td>
#       <td id="T_91d35_row9_col1" class="data row9 col1" >92996362240.0000</td>
#       <td id="T_91d35_row9_col2" class="data row9 col2" >304953.0625</td>
#       <td id="T_91d35_row9_col3" class="data row9 col3" >0.9270</td>
#       <td id="T_91d35_row9_col4" class="data row9 col4" >0.3060</td>
#       <td id="T_91d35_row9_col5" class="data row9 col5" >0.2346</td>
#     </tr>
#     <tr>
#       <th id="T_91d35_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_91d35_row10_col0" class="data row10 col0" >164212.9766</td>
#       <td id="T_91d35_row10_col1" class="data row10 col1" >135114595532.8000</td>
#       <td id="T_91d35_row10_col2" class="data row10 col2" >354901.3812</td>
#       <td id="T_91d35_row10_col3" class="data row10 col3" >0.8972</td>
#       <td id="T_91d35_row10_col4" class="data row10 col4" >0.2630</td>
#       <td id="T_91d35_row10_col5" class="data row10 col5" >0.2092</td>
#     </tr>
#     <tr>
#       <th id="T_91d35_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_91d35_row11_col0" class="data row11 col0" >11442.8385</td>
#       <td id="T_91d35_row11_col1" class="data row11 col1" >81142939209.6458</td>
#       <td id="T_91d35_row11_col2" class="data row11 col2" >95705.8316</td>
#       <td id="T_91d35_row11_col3" class="data row11 col3" >0.0425</td>
#       <td id="T_91d35_row11_col4" class="data row11 col4" >0.0184</td>
#       <td id="T_91d35_row11_col5" class="data row11 col5" >0.0156</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# <style type="text/css">
# #T_aeda7_row10_col0, #T_aeda7_row10_col1, #T_aeda7_row10_col2, #T_aeda7_row10_col3, #T_aeda7_row10_col4, #T_aeda7_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_aeda7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aeda7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_aeda7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_aeda7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_aeda7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_aeda7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_aeda7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aeda7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aeda7_row0_col0" class="data row0 col0" >147505.8449</td>
#       <td id="T_aeda7_row0_col1" class="data row0 col1" >85654437050.5715</td>
#       <td id="T_aeda7_row0_col2" class="data row0 col2" >292667.7930</td>
#       <td id="T_aeda7_row0_col3" class="data row0 col3" >0.9257</td>
#       <td id="T_aeda7_row0_col4" class="data row0 col4" >0.2435</td>
#       <td id="T_aeda7_row0_col5" class="data row0 col5" >0.1898</td>
#     </tr>
#     <tr>
#       <th id="T_aeda7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aeda7_row1_col0" class="data row1 col0" >178318.7008</td>
#       <td id="T_aeda7_row1_col1" class="data row1 col1" >276986122644.2210</td>
#       <td id="T_aeda7_row1_col2" class="data row1 col2" >526294.7108</td>
#       <td id="T_aeda7_row1_col3" class="data row1 col3" >0.8119</td>
#       <td id="T_aeda7_row1_col4" class="data row1 col4" >0.2437</td>
#       <td id="T_aeda7_row1_col5" class="data row1 col5" >0.1748</td>
#     </tr>
#     <tr>
#       <th id="T_aeda7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aeda7_row2_col0" class="data row2 col0" >183692.0797</td>
#       <td id="T_aeda7_row2_col1" class="data row2 col1" >124032074213.0112</td>
#       <td id="T_aeda7_row2_col2" class="data row2 col2" >352181.8766</td>
#       <td id="T_aeda7_row2_col3" class="data row2 col3" >0.9106</td>
#       <td id="T_aeda7_row2_col4" class="data row2 col4" >0.2600</td>
#       <td id="T_aeda7_row2_col5" class="data row2 col5" >0.2142</td>
#     </tr>
#     <tr>
#       <th id="T_aeda7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aeda7_row3_col0" class="data row3 col0" >161070.9300</td>
#       <td id="T_aeda7_row3_col1" class="data row3 col1" >114303394646.4894</td>
#       <td id="T_aeda7_row3_col2" class="data row3 col2" >338087.8505</td>
#       <td id="T_aeda7_row3_col3" class="data row3 col3" >0.8720</td>
#       <td id="T_aeda7_row3_col4" class="data row3 col4" >0.2710</td>
#       <td id="T_aeda7_row3_col5" class="data row3 col5" >0.2103</td>
#     </tr>
#     <tr>
#       <th id="T_aeda7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aeda7_row4_col0" class="data row4 col0" >145419.2683</td>
#       <td id="T_aeda7_row4_col1" class="data row4 col1" >78801334075.3254</td>
#       <td id="T_aeda7_row4_col2" class="data row4 col2" >280715.7532</td>
#       <td id="T_aeda7_row4_col3" class="data row4 col3" >0.9428</td>
#       <td id="T_aeda7_row4_col4" class="data row4 col4" >0.2362</td>
#       <td id="T_aeda7_row4_col5" class="data row4 col5" >0.1877</td>
#     </tr>
#     <tr>
#       <th id="T_aeda7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aeda7_row5_col0" class="data row5 col0" >162636.7859</td>
#       <td id="T_aeda7_row5_col1" class="data row5 col1" >94669468325.2920</td>
#       <td id="T_aeda7_row5_col2" class="data row5 col2" >307684.0398</td>
#       <td id="T_aeda7_row5_col3" class="data row5 col3" >0.9116</td>
#       <td id="T_aeda7_row5_col4" class="data row5 col4" >0.2633</td>
#       <td id="T_aeda7_row5_col5" class="data row5 col5" >0.1991</td>
#     </tr>
#     <tr>
#       <th id="T_aeda7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aeda7_row6_col0" class="data row6 col0" >175697.4059</td>
#       <td id="T_aeda7_row6_col1" class="data row6 col1" >329089234618.6413</td>
#       <td id="T_aeda7_row6_col2" class="data row6 col2" >573662.9974</td>
#       <td id="T_aeda7_row6_col3" class="data row6 col3" >0.8027</td>
#       <td id="T_aeda7_row6_col4" class="data row6 col4" >0.2809</td>
#       <td id="T_aeda7_row6_col5" class="data row6 col5" >0.2348</td>
#     </tr>
#     <tr>
#       <th id="T_aeda7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aeda7_row7_col0" class="data row7 col0" >168798.1369</td>
#       <td id="T_aeda7_row7_col1" class="data row7 col1" >128676203968.6000</td>
#       <td id="T_aeda7_row7_col2" class="data row7 col2" >358714.6554</td>
#       <td id="T_aeda7_row7_col3" class="data row7 col3" >0.8990</td>
#       <td id="T_aeda7_row7_col4" class="data row7 col4" >0.2737</td>
#       <td id="T_aeda7_row7_col5" class="data row7 col5" >0.1948</td>
#     </tr>
#     <tr>
#       <th id="T_aeda7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aeda7_row8_col0" class="data row8 col0" >144655.9689</td>
#       <td id="T_aeda7_row8_col1" class="data row8 col1" >67911899144.8590</td>
#       <td id="T_aeda7_row8_col2" class="data row8 col2" >260599.1158</td>
#       <td id="T_aeda7_row8_col3" class="data row8 col3" >0.9302</td>
#       <td id="T_aeda7_row8_col4" class="data row8 col4" >0.2658</td>
#       <td id="T_aeda7_row8_col5" class="data row8 col5" >0.2098</td>
#     </tr>
#     <tr>
#       <th id="T_aeda7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aeda7_row9_col0" class="data row9 col0" >160501.6917</td>
#       <td id="T_aeda7_row9_col1" class="data row9 col1" >94526815481.4672</td>
#       <td id="T_aeda7_row9_col2" class="data row9 col2" >307452.1353</td>
#       <td id="T_aeda7_row9_col3" class="data row9 col3" >0.9258</td>
#       <td id="T_aeda7_row9_col4" class="data row9 col4" >0.3346</td>
#       <td id="T_aeda7_row9_col5" class="data row9 col5" >0.2163</td>
#     </tr>
#     <tr>
#       <th id="T_aeda7_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_aeda7_row10_col0" class="data row10 col0" >162829.6813</td>
#       <td id="T_aeda7_row10_col1" class="data row10 col1" >139465098416.8478</td>
#       <td id="T_aeda7_row10_col2" class="data row10 col2" >359806.0928</td>
#       <td id="T_aeda7_row10_col3" class="data row10 col3" >0.8932</td>
#       <td id="T_aeda7_row10_col4" class="data row10 col4" >0.2673</td>
#       <td id="T_aeda7_row10_col5" class="data row10 col5" >0.2032</td>
#     </tr>
#     <tr>
#       <th id="T_aeda7_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_aeda7_row11_col0" class="data row11 col0" >13240.5680</td>
#       <td id="T_aeda7_row11_col1" class="data row11 col1" >84604179924.0662</td>
#       <td id="T_aeda7_row11_col2" class="data row11 col2" >100023.3674</td>
#       <td id="T_aeda7_row11_col3" class="data row11 col3" >0.0468</td>
#       <td id="T_aeda7_row11_col4" class="data row11 col4" >0.0263</td>
#       <td id="T_aeda7_row11_col5" class="data row11 col5" >0.0164</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_6eb07_row10_col0, #T_6eb07_row10_col1, #T_6eb07_row10_col2, #T_6eb07_row10_col3, #T_6eb07_row10_col4, #T_6eb07_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6eb07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6eb07_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6eb07_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6eb07_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6eb07_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6eb07_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6eb07_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6eb07_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6eb07_row0_col0" class="data row0 col0" >263025.2851</td>
#       <td id="T_6eb07_row0_col1" class="data row0 col1" >249310717042.2098</td>
#       <td id="T_6eb07_row0_col2" class="data row0 col2" >499310.2413</td>
#       <td id="T_6eb07_row0_col3" class="data row0 col3" >0.7836</td>
#       <td id="T_6eb07_row0_col4" class="data row0 col4" >0.4026</td>
#       <td id="T_6eb07_row0_col5" class="data row0 col5" >0.3812</td>
#     </tr>
#     <tr>
#       <th id="T_6eb07_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6eb07_row1_col0" class="data row1 col0" >242869.7996</td>
#       <td id="T_6eb07_row1_col1" class="data row1 col1" >362962061638.0772</td>
#       <td id="T_6eb07_row1_col2" class="data row1 col2" >602463.3280</td>
#       <td id="T_6eb07_row1_col3" class="data row1 col3" >0.7536</td>
#       <td id="T_6eb07_row1_col4" class="data row1 col4" >0.3459</td>
#       <td id="T_6eb07_row1_col5" class="data row1 col5" >0.3020</td>
#     </tr>
#     <tr>
#       <th id="T_6eb07_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6eb07_row2_col0" class="data row2 col0" >275898.4085</td>
#       <td id="T_6eb07_row2_col1" class="data row2 col1" >283166825158.7280</td>
#       <td id="T_6eb07_row2_col2" class="data row2 col2" >532134.2172</td>
#       <td id="T_6eb07_row2_col3" class="data row2 col3" >0.7959</td>
#       <td id="T_6eb07_row2_col4" class="data row2 col4" >0.3856</td>
#       <td id="T_6eb07_row2_col5" class="data row2 col5" >0.3616</td>
#     </tr>
#     <tr>
#       <th id="T_6eb07_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6eb07_row3_col0" class="data row3 col0" >207886.3924</td>
#       <td id="T_6eb07_row3_col1" class="data row3 col1" >117230906135.0284</td>
#       <td id="T_6eb07_row3_col2" class="data row3 col2" >342389.9913</td>
#       <td id="T_6eb07_row3_col3" class="data row3 col3" >0.8687</td>
#       <td id="T_6eb07_row3_col4" class="data row3 col4" >0.3434</td>
#       <td id="T_6eb07_row3_col5" class="data row3 col5" >0.3125</td>
#     </tr>
#     <tr>
#       <th id="T_6eb07_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6eb07_row4_col0" class="data row4 col0" >252479.2425</td>
#       <td id="T_6eb07_row4_col1" class="data row4 col1" >274001431240.4878</td>
#       <td id="T_6eb07_row4_col2" class="data row4 col2" >523451.4603</td>
#       <td id="T_6eb07_row4_col3" class="data row4 col3" >0.8011</td>
#       <td id="T_6eb07_row4_col4" class="data row4 col4" >0.3627</td>
#       <td id="T_6eb07_row4_col5" class="data row4 col5" >0.3297</td>
#     </tr>
#     <tr>
#       <th id="T_6eb07_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6eb07_row5_col0" class="data row5 col0" >243365.2662</td>
#       <td id="T_6eb07_row5_col1" class="data row5 col1" >214939963310.7125</td>
#       <td id="T_6eb07_row5_col2" class="data row5 col2" >463616.1810</td>
#       <td id="T_6eb07_row5_col3" class="data row5 col3" >0.7994</td>
#       <td id="T_6eb07_row5_col4" class="data row5 col4" >0.3900</td>
#       <td id="T_6eb07_row5_col5" class="data row5 col5" >0.3461</td>
#     </tr>
#     <tr>
#       <th id="T_6eb07_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6eb07_row6_col0" class="data row6 col0" >259291.0947</td>
#       <td id="T_6eb07_row6_col1" class="data row6 col1" >468803618156.5866</td>
#       <td id="T_6eb07_row6_col2" class="data row6 col2" >684692.3529</td>
#       <td id="T_6eb07_row6_col3" class="data row6 col3" >0.7189</td>
#       <td id="T_6eb07_row6_col4" class="data row6 col4" >0.3806</td>
#       <td id="T_6eb07_row6_col5" class="data row6 col5" >0.3578</td>
#     </tr>
#     <tr>
#       <th id="T_6eb07_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6eb07_row7_col0" class="data row7 col0" >282378.1879</td>
#       <td id="T_6eb07_row7_col1" class="data row7 col1" >248716195528.2556</td>
#       <td id="T_6eb07_row7_col2" class="data row7 col2" >498714.5431</td>
#       <td id="T_6eb07_row7_col3" class="data row7 col3" >0.8048</td>
#       <td id="T_6eb07_row7_col4" class="data row7 col4" >0.4087</td>
#       <td id="T_6eb07_row7_col5" class="data row7 col5" >0.3911</td>
#     </tr>
#     <tr>
#       <th id="T_6eb07_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6eb07_row8_col0" class="data row8 col0" >220510.4652</td>
#       <td id="T_6eb07_row8_col1" class="data row8 col1" >126130008587.3736</td>
#       <td id="T_6eb07_row8_col2" class="data row8 col2" >355147.8686</td>
#       <td id="T_6eb07_row8_col3" class="data row8 col3" >0.8704</td>
#       <td id="T_6eb07_row8_col4" class="data row8 col4" >0.3785</td>
#       <td id="T_6eb07_row8_col5" class="data row8 col5" >0.3595</td>
#     </tr>
#     <tr>
#       <th id="T_6eb07_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6eb07_row9_col0" class="data row9 col0" >264344.3721</td>
#       <td id="T_6eb07_row9_col1" class="data row9 col1" >226935017991.2459</td>
#       <td id="T_6eb07_row9_col2" class="data row9 col2" >476376.9705</td>
#       <td id="T_6eb07_row9_col3" class="data row9 col3" >0.8220</td>
#       <td id="T_6eb07_row9_col4" class="data row9 col4" >0.4179</td>
#       <td id="T_6eb07_row9_col5" class="data row9 col5" >0.3931</td>
#     </tr>
#     <tr>
#       <th id="T_6eb07_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6eb07_row10_col0" class="data row10 col0" >251204.8514</td>
#       <td id="T_6eb07_row10_col1" class="data row10 col1" >257219674478.8706</td>
#       <td id="T_6eb07_row10_col2" class="data row10 col2" >497829.7154</td>
#       <td id="T_6eb07_row10_col3" class="data row10 col3" >0.8018</td>
#       <td id="T_6eb07_row10_col4" class="data row10 col4" >0.3816</td>
#       <td id="T_6eb07_row10_col5" class="data row10 col5" >0.3535</td>
#     </tr>
#     <tr>
#       <th id="T_6eb07_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6eb07_row11_col0" class="data row11 col0" >22159.6393</td>
#       <td id="T_6eb07_row11_col1" class="data row11 col1" >98247163101.9221</td>
#       <td id="T_6eb07_row11_col2" class="data row11 col2" >96877.4944</td>
#       <td id="T_6eb07_row11_col3" class="data row11 col3" >0.0438</td>
#       <td id="T_6eb07_row11_col4" class="data row11 col4" >0.0238</td>
#       <td id="T_6eb07_row11_col5" class="data row11 col5" >0.0297</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_8e93f_row10_col0, #T_8e93f_row10_col1, #T_8e93f_row10_col2, #T_8e93f_row10_col3, #T_8e93f_row10_col4, #T_8e93f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8e93f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e93f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8e93f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8e93f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8e93f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8e93f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8e93f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e93f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e93f_row0_col0" class="data row0 col0" >156700.2396</td>
#       <td id="T_8e93f_row0_col1" class="data row0 col1" >102778491050.3046</td>
#       <td id="T_8e93f_row0_col2" class="data row0 col2" >320590.8468</td>
#       <td id="T_8e93f_row0_col3" class="data row0 col3" >0.9108</td>
#       <td id="T_8e93f_row0_col4" class="data row0 col4" >0.2596</td>
#       <td id="T_8e93f_row0_col5" class="data row0 col5" >0.2066</td>
#     </tr>
#     <tr>
#       <th id="T_8e93f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8e93f_row1_col0" class="data row1 col0" >175837.4062</td>
#       <td id="T_8e93f_row1_col1" class="data row1 col1" >297075947195.7447</td>
#       <td id="T_8e93f_row1_col2" class="data row1 col2" >545046.7385</td>
#       <td id="T_8e93f_row1_col3" class="data row1 col3" >0.7983</td>
#       <td id="T_8e93f_row1_col4" class="data row1 col4" >0.2370</td>
#       <td id="T_8e93f_row1_col5" class="data row1 col5" >0.1789</td>
#     </tr>
#     <tr>
#       <th id="T_8e93f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8e93f_row2_col0" class="data row2 col0" >195648.4271</td>
#       <td id="T_8e93f_row2_col1" class="data row2 col1" >178460089721.8668</td>
#       <td id="T_8e93f_row2_col2" class="data row2 col2" >422445.3689</td>
#       <td id="T_8e93f_row2_col3" class="data row2 col3" >0.8714</td>
#       <td id="T_8e93f_row2_col4" class="data row2 col4" >0.2585</td>
#       <td id="T_8e93f_row2_col5" class="data row2 col5" >0.2134</td>
#     </tr>
#     <tr>
#       <th id="T_8e93f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8e93f_row3_col0" class="data row3 col0" >160295.1841</td>
#       <td id="T_8e93f_row3_col1" class="data row3 col1" >95037306147.7933</td>
#       <td id="T_8e93f_row3_col2" class="data row3 col2" >308281.2128</td>
#       <td id="T_8e93f_row3_col3" class="data row3 col3" >0.8936</td>
#       <td id="T_8e93f_row3_col4" class="data row3 col4" >0.2555</td>
#       <td id="T_8e93f_row3_col5" class="data row3 col5" >0.2076</td>
#     </tr>
#     <tr>
#       <th id="T_8e93f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8e93f_row4_col0" class="data row4 col0" >152476.1454</td>
#       <td id="T_8e93f_row4_col1" class="data row4 col1" >91399549687.0635</td>
#       <td id="T_8e93f_row4_col2" class="data row4 col2" >302323.5844</td>
#       <td id="T_8e93f_row4_col3" class="data row4 col3" >0.9336</td>
#       <td id="T_8e93f_row4_col4" class="data row4 col4" >0.2430</td>
#       <td id="T_8e93f_row4_col5" class="data row4 col5" >0.1971</td>
#     </tr>
#     <tr>
#       <th id="T_8e93f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8e93f_row5_col0" class="data row5 col0" >161236.2069</td>
#       <td id="T_8e93f_row5_col1" class="data row5 col1" >105482454479.3359</td>
#       <td id="T_8e93f_row5_col2" class="data row5 col2" >324780.6252</td>
#       <td id="T_8e93f_row5_col3" class="data row5 col3" >0.9016</td>
#       <td id="T_8e93f_row5_col4" class="data row5 col4" >0.2614</td>
#       <td id="T_8e93f_row5_col5" class="data row5 col5" >0.2006</td>
#     </tr>
#     <tr>
#       <th id="T_8e93f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8e93f_row6_col0" class="data row6 col0" >179271.0559</td>
#       <td id="T_8e93f_row6_col1" class="data row6 col1" >350434641162.3024</td>
#       <td id="T_8e93f_row6_col2" class="data row6 col2" >591975.2032</td>
#       <td id="T_8e93f_row6_col3" class="data row6 col3" >0.7899</td>
#       <td id="T_8e93f_row6_col4" class="data row6 col4" >0.2744</td>
#       <td id="T_8e93f_row6_col5" class="data row6 col5" >0.2228</td>
#     </tr>
#     <tr>
#       <th id="T_8e93f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8e93f_row7_col0" class="data row7 col0" >176696.5709</td>
#       <td id="T_8e93f_row7_col1" class="data row7 col1" >133044133555.9455</td>
#       <td id="T_8e93f_row7_col2" class="data row7 col2" >364752.1536</td>
#       <td id="T_8e93f_row7_col3" class="data row7 col3" >0.8956</td>
#       <td id="T_8e93f_row7_col4" class="data row7 col4" >0.2704</td>
#       <td id="T_8e93f_row7_col5" class="data row7 col5" >0.2203</td>
#     </tr>
#     <tr>
#       <th id="T_8e93f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8e93f_row8_col0" class="data row8 col0" >143317.7217</td>
#       <td id="T_8e93f_row8_col1" class="data row8 col1" >62770724396.9971</td>
#       <td id="T_8e93f_row8_col2" class="data row8 col2" >250540.8637</td>
#       <td id="T_8e93f_row8_col3" class="data row8 col3" >0.9355</td>
#       <td id="T_8e93f_row8_col4" class="data row8 col4" >0.2616</td>
#       <td id="T_8e93f_row8_col5" class="data row8 col5" >0.2108</td>
#     </tr>
#     <tr>
#       <th id="T_8e93f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8e93f_row9_col0" class="data row9 col0" >176224.8215</td>
#       <td id="T_8e93f_row9_col1" class="data row9 col1" >106350454690.2349</td>
#       <td id="T_8e93f_row9_col2" class="data row9 col2" >326114.1743</td>
#       <td id="T_8e93f_row9_col3" class="data row9 col3" >0.9166</td>
#       <td id="T_8e93f_row9_col4" class="data row9 col4" >0.2840</td>
#       <td id="T_8e93f_row9_col5" class="data row9 col5" >0.2358</td>
#     </tr>
#     <tr>
#       <th id="T_8e93f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8e93f_row10_col0" class="data row10 col0" >167770.3779</td>
#       <td id="T_8e93f_row10_col1" class="data row10 col1" >152283379208.7588</td>
#       <td id="T_8e93f_row10_col2" class="data row10 col2" >375685.0771</td>
#       <td id="T_8e93f_row10_col3" class="data row10 col3" >0.8847</td>
#       <td id="T_8e93f_row10_col4" class="data row10 col4" >0.2605</td>
#       <td id="T_8e93f_row10_col5" class="data row10 col5" >0.2094</td>
#     </tr>
#     <tr>
#       <th id="T_8e93f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8e93f_row11_col0" class="data row11 col0" >14760.2524</td>
#       <td id="T_8e93f_row11_col1" class="data row11 col1" >91121645132.2827</td>
#       <td id="T_8e93f_row11_col2" class="data row11 col2" >105565.6290</td>
#       <td id="T_8e93f_row11_col3" class="data row11 col3" >0.0488</td>
#       <td id="T_8e93f_row11_col4" class="data row11 col4" >0.0132</td>
#       <td id="T_8e93f_row11_col5" class="data row11 col5" >0.0148</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
#               MAE           MSE         RMSE      R2   RMSLE    MAPE
# Fold
# 0     156700.2396  1.027785e+11  320590.8468  0.9108  0.2596  0.2066
# 1     175837.4062  2.970759e+11  545046.7385  0.7983  0.2370  0.1789
# 2     195648.4271  1.784601e+11  422445.3689  0.8714  0.2585  0.2134
# 3     160295.1841  9.503731e+10  308281.2128  0.8936  0.2555  0.2076
# 4     152476.1454  9.139955e+10  302323.5844  0.9336  0.2430  0.1971
# 5     161236.2069  1.054825e+11  324780.6252  0.9016  0.2614  0.2006
# 6     179271.0559  3.504346e+11  591975.2032  0.7899  0.2744  0.2228
# 7     176696.5709  1.330441e+11  364752.1536  0.8956  0.2704  0.2203
# 8     143317.7217  6.277072e+10  250540.8637  0.9355  0.2616  0.2108
# 9     176224.8215  1.063505e+11  326114.1743  0.9166  0.2840  0.2358
# Mean  167770.3779  1.522834e+11  375685.0771  0.8847  0.2605  0.2094
# Std    14760.2524  9.112165e+10  105565.6290  0.0488  0.0132  0.0148

# %% [markdown]
# ## Blend & Stack Models

# %%
blended = blend_models(estimator_list=tuned_models, optimize="R2")
meta = create_model("lightgbm")
stacked = stack_models(estimator_list=tuned_models, meta_model=meta, optimize="R2")
# Out:
# <style type="text/css">
# #T_c24f2_row10_col0, #T_c24f2_row10_col1, #T_c24f2_row10_col2, #T_c24f2_row10_col3, #T_c24f2_row10_col4, #T_c24f2_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c24f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c24f2_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c24f2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c24f2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c24f2_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c24f2_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c24f2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c24f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c24f2_row0_col0" class="data row0 col0" >143016.1947</td>
#       <td id="T_c24f2_row0_col1" class="data row0 col1" >80836340715.4829</td>
#       <td id="T_c24f2_row0_col2" class="data row0 col2" >284317.3240</td>
#       <td id="T_c24f2_row0_col3" class="data row0 col3" >0.9298</td>
#       <td id="T_c24f2_row0_col4" class="data row0 col4" >0.2350</td>
#       <td id="T_c24f2_row0_col5" class="data row0 col5" >0.1848</td>
#     </tr>
#     <tr>
#       <th id="T_c24f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c24f2_row1_col0" class="data row1 col0" >163090.5989</td>
#       <td id="T_c24f2_row1_col1" class="data row1 col1" >259478792406.7036</td>
#       <td id="T_c24f2_row1_col2" class="data row1 col2" >509390.6089</td>
#       <td id="T_c24f2_row1_col3" class="data row1 col3" >0.8238</td>
#       <td id="T_c24f2_row1_col4" class="data row1 col4" >0.2150</td>
#       <td id="T_c24f2_row1_col5" class="data row1 col5" >0.1611</td>
#     </tr>
#     <tr>
#       <th id="T_c24f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c24f2_row2_col0" class="data row2 col0" >168851.1498</td>
#       <td id="T_c24f2_row2_col1" class="data row2 col1" >104104832137.2697</td>
#       <td id="T_c24f2_row2_col2" class="data row2 col2" >322652.8043</td>
#       <td id="T_c24f2_row2_col3" class="data row2 col3" >0.9250</td>
#       <td id="T_c24f2_row2_col4" class="data row2 col4" >0.2387</td>
#       <td id="T_c24f2_row2_col5" class="data row2 col5" >0.1949</td>
#     </tr>
#     <tr>
#       <th id="T_c24f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c24f2_row3_col0" class="data row3 col0" >146929.8761</td>
#       <td id="T_c24f2_row3_col1" class="data row3 col1" >82958579291.8495</td>
#       <td id="T_c24f2_row3_col2" class="data row3 col2" >288025.3102</td>
#       <td id="T_c24f2_row3_col3" class="data row3 col3" >0.9071</td>
#       <td id="T_c24f2_row3_col4" class="data row3 col4" >0.2343</td>
#       <td id="T_c24f2_row3_col5" class="data row3 col5" >0.1872</td>
#     </tr>
#     <tr>
#       <th id="T_c24f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c24f2_row4_col0" class="data row4 col0" >139884.4058</td>
#       <td id="T_c24f2_row4_col1" class="data row4 col1" >71590856061.0532</td>
#       <td id="T_c24f2_row4_col2" class="data row4 col2" >267564.6764</td>
#       <td id="T_c24f2_row4_col3" class="data row4 col3" >0.9480</td>
#       <td id="T_c24f2_row4_col4" class="data row4 col4" >0.2202</td>
#       <td id="T_c24f2_row4_col5" class="data row4 col5" >0.1775</td>
#     </tr>
#     <tr>
#       <th id="T_c24f2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c24f2_row5_col0" class="data row5 col0" >149582.8011</td>
#       <td id="T_c24f2_row5_col1" class="data row5 col1" >92861808725.2686</td>
#       <td id="T_c24f2_row5_col2" class="data row5 col2" >304732.3559</td>
#       <td id="T_c24f2_row5_col3" class="data row5 col3" >0.9133</td>
#       <td id="T_c24f2_row5_col4" class="data row5 col4" >0.2409</td>
#       <td id="T_c24f2_row5_col5" class="data row5 col5" >0.1804</td>
#     </tr>
#     <tr>
#       <th id="T_c24f2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c24f2_row6_col0" class="data row6 col0" >164254.9594</td>
#       <td id="T_c24f2_row6_col1" class="data row6 col1" >328947176493.2176</td>
#       <td id="T_c24f2_row6_col2" class="data row6 col2" >573539.1674</td>
#       <td id="T_c24f2_row6_col3" class="data row6 col3" >0.8028</td>
#       <td id="T_c24f2_row6_col4" class="data row6 col4" >0.2733</td>
#       <td id="T_c24f2_row6_col5" class="data row6 col5" >0.2357</td>
#     </tr>
#     <tr>
#       <th id="T_c24f2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c24f2_row7_col0" class="data row7 col0" >164123.7131</td>
#       <td id="T_c24f2_row7_col1" class="data row7 col1" >125776477521.0735</td>
#       <td id="T_c24f2_row7_col2" class="data row7 col2" >354649.7956</td>
#       <td id="T_c24f2_row7_col3" class="data row7 col3" >0.9013</td>
#       <td id="T_c24f2_row7_col4" class="data row7 col4" >0.2484</td>
#       <td id="T_c24f2_row7_col5" class="data row7 col5" >0.1969</td>
#     </tr>
#     <tr>
#       <th id="T_c24f2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c24f2_row8_col0" class="data row8 col0" >132188.2930</td>
#       <td id="T_c24f2_row8_col1" class="data row8 col1" >57255734031.9766</td>
#       <td id="T_c24f2_row8_col2" class="data row8 col2" >239281.7043</td>
#       <td id="T_c24f2_row8_col3" class="data row8 col3" >0.9412</td>
#       <td id="T_c24f2_row8_col4" class="data row8 col4" >0.2390</td>
#       <td id="T_c24f2_row8_col5" class="data row8 col5" >0.1898</td>
#     </tr>
#     <tr>
#       <th id="T_c24f2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c24f2_row9_col0" class="data row9 col0" >151040.1387</td>
#       <td id="T_c24f2_row9_col1" class="data row9 col1" >76898588189.9876</td>
#       <td id="T_c24f2_row9_col2" class="data row9 col2" >277305.9469</td>
#       <td id="T_c24f2_row9_col3" class="data row9 col3" >0.9397</td>
#       <td id="T_c24f2_row9_col4" class="data row9 col4" >0.2550</td>
#       <td id="T_c24f2_row9_col5" class="data row9 col5" >0.2039</td>
#     </tr>
#     <tr>
#       <th id="T_c24f2_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c24f2_row10_col0" class="data row10 col0" >152296.2130</td>
#       <td id="T_c24f2_row10_col1" class="data row10 col1" >128070918557.3883</td>
#       <td id="T_c24f2_row10_col2" class="data row10 col2" >342145.9694</td>
#       <td id="T_c24f2_row10_col3" class="data row10 col3" >0.9032</td>
#       <td id="T_c24f2_row10_col4" class="data row10 col4" >0.2400</td>
#       <td id="T_c24f2_row10_col5" class="data row10 col5" >0.1912</td>
#     </tr>
#     <tr>
#       <th id="T_c24f2_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c24f2_row11_col0" class="data row11 col0" >11643.5567</td>
#       <td id="T_c24f2_row11_col1" class="data row11 col1" >86329741802.6579</td>
#       <td id="T_c24f2_row11_col2" class="data row11 col2" >104914.5090</td>
#       <td id="T_c24f2_row11_col3" class="data row11 col3" >0.0474</td>
#       <td id="T_c24f2_row11_col4" class="data row11 col4" >0.0158</td>
#       <td id="T_c24f2_row11_col5" class="data row11 col5" >0.0186</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9adcb_row10_col0, #T_9adcb_row10_col1, #T_9adcb_row10_col2, #T_9adcb_row10_col3, #T_9adcb_row10_col4, #T_9adcb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_9adcb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9adcb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9adcb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9adcb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9adcb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_9adcb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_9adcb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9adcb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9adcb_row0_col0" class="data row0 col0" >154179.4086</td>
#       <td id="T_9adcb_row0_col1" class="data row0 col1" >92176079923.7180</td>
#       <td id="T_9adcb_row0_col2" class="data row0 col2" >303605.1382</td>
#       <td id="T_9adcb_row0_col3" class="data row0 col3" >0.9200</td>
#       <td id="T_9adcb_row0_col4" class="data row0 col4" >0.2539</td>
#       <td id="T_9adcb_row0_col5" class="data row0 col5" >0.2011</td>
#     </tr>
#     <tr>
#       <th id="T_9adcb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9adcb_row1_col0" class="data row1 col0" >174550.8938</td>
#       <td id="T_9adcb_row1_col1" class="data row1 col1" >272861620694.9100</td>
#       <td id="T_9adcb_row1_col2" class="data row1 col2" >522361.5804</td>
#       <td id="T_9adcb_row1_col3" class="data row1 col3" >0.8147</td>
#       <td id="T_9adcb_row1_col4" class="data row1 col4" >0.2310</td>
#       <td id="T_9adcb_row1_col5" class="data row1 col5" >0.1743</td>
#     </tr>
#     <tr>
#       <th id="T_9adcb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9adcb_row2_col0" class="data row2 col0" >181546.8902</td>
#       <td id="T_9adcb_row2_col1" class="data row2 col1" >126764781718.9275</td>
#       <td id="T_9adcb_row2_col2" class="data row2 col2" >356040.4215</td>
#       <td id="T_9adcb_row2_col3" class="data row2 col3" >0.9086</td>
#       <td id="T_9adcb_row2_col4" class="data row2 col4" >0.2614</td>
#       <td id="T_9adcb_row2_col5" class="data row2 col5" >0.2111</td>
#     </tr>
#     <tr>
#       <th id="T_9adcb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9adcb_row3_col0" class="data row3 col0" >157835.5283</td>
#       <td id="T_9adcb_row3_col1" class="data row3 col1" >99848871189.3838</td>
#       <td id="T_9adcb_row3_col2" class="data row3 col2" >315988.7200</td>
#       <td id="T_9adcb_row3_col3" class="data row3 col3" >0.8882</td>
#       <td id="T_9adcb_row3_col4" class="data row3 col4" >0.3387</td>
#       <td id="T_9adcb_row3_col5" class="data row3 col5" >0.2039</td>
#     </tr>
#     <tr>
#       <th id="T_9adcb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9adcb_row4_col0" class="data row4 col0" >146246.9552</td>
#       <td id="T_9adcb_row4_col1" class="data row4 col1" >74197804528.9400</td>
#       <td id="T_9adcb_row4_col2" class="data row4 col2" >272392.7395</td>
#       <td id="T_9adcb_row4_col3" class="data row4 col3" >0.9461</td>
#       <td id="T_9adcb_row4_col4" class="data row4 col4" >0.2422</td>
#       <td id="T_9adcb_row4_col5" class="data row4 col5" >0.1940</td>
#     </tr>
#     <tr>
#       <th id="T_9adcb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9adcb_row5_col0" class="data row5 col0" >159033.4351</td>
#       <td id="T_9adcb_row5_col1" class="data row5 col1" >104229357169.0507</td>
#       <td id="T_9adcb_row5_col2" class="data row5 col2" >322845.7173</td>
#       <td id="T_9adcb_row5_col3" class="data row5 col3" >0.9027</td>
#       <td id="T_9adcb_row5_col4" class="data row5 col4" >0.2677</td>
#       <td id="T_9adcb_row5_col5" class="data row5 col5" >0.1905</td>
#     </tr>
#     <tr>
#       <th id="T_9adcb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9adcb_row6_col0" class="data row6 col0" >175368.1609</td>
#       <td id="T_9adcb_row6_col1" class="data row6 col1" >321740144696.6518</td>
#       <td id="T_9adcb_row6_col2" class="data row6 col2" >567221.4248</td>
#       <td id="T_9adcb_row6_col3" class="data row6 col3" >0.8071</td>
#       <td id="T_9adcb_row6_col4" class="data row6 col4" >0.2706</td>
#       <td id="T_9adcb_row6_col5" class="data row6 col5" >0.2202</td>
#     </tr>
#     <tr>
#       <th id="T_9adcb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9adcb_row7_col0" class="data row7 col0" >169099.3824</td>
#       <td id="T_9adcb_row7_col1" class="data row7 col1" >135569933410.5112</td>
#       <td id="T_9adcb_row7_col2" class="data row7 col2" >368198.2257</td>
#       <td id="T_9adcb_row7_col3" class="data row7 col3" >0.8936</td>
#       <td id="T_9adcb_row7_col4" class="data row7 col4" >0.2625</td>
#       <td id="T_9adcb_row7_col5" class="data row7 col5" >0.2088</td>
#     </tr>
#     <tr>
#       <th id="T_9adcb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9adcb_row8_col0" class="data row8 col0" >139512.0688</td>
#       <td id="T_9adcb_row8_col1" class="data row8 col1" >72467011185.2536</td>
#       <td id="T_9adcb_row8_col2" class="data row8 col2" >269196.9747</td>
#       <td id="T_9adcb_row8_col3" class="data row8 col3" >0.9256</td>
#       <td id="T_9adcb_row8_col4" class="data row8 col4" >0.2557</td>
#       <td id="T_9adcb_row8_col5" class="data row8 col5" >0.2028</td>
#     </tr>
#     <tr>
#       <th id="T_9adcb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9adcb_row9_col0" class="data row9 col0" >169163.2892</td>
#       <td id="T_9adcb_row9_col1" class="data row9 col1" >94634127709.7660</td>
#       <td id="T_9adcb_row9_col2" class="data row9 col2" >307626.6044</td>
#       <td id="T_9adcb_row9_col3" class="data row9 col3" >0.9258</td>
#       <td id="T_9adcb_row9_col4" class="data row9 col4" >0.3359</td>
#       <td id="T_9adcb_row9_col5" class="data row9 col5" >0.2275</td>
#     </tr>
#     <tr>
#       <th id="T_9adcb_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9adcb_row10_col0" class="data row10 col0" >162653.6012</td>
#       <td id="T_9adcb_row10_col1" class="data row10 col1" >139448973222.7112</td>
#       <td id="T_9adcb_row10_col2" class="data row10 col2" >360547.7546</td>
#       <td id="T_9adcb_row10_col3" class="data row10 col3" >0.8932</td>
#       <td id="T_9adcb_row10_col4" class="data row10 col4" >0.2720</td>
#       <td id="T_9adcb_row10_col5" class="data row10 col5" >0.2034</td>
#     </tr>
#     <tr>
#       <th id="T_9adcb_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9adcb_row11_col0" class="data row11 col0" >12872.1639</td>
#       <td id="T_9adcb_row11_col1" class="data row11 col1" >81854093285.7770</td>
#       <td id="T_9adcb_row11_col2" class="data row11 col2" >97233.1726</td>
#       <td id="T_9adcb_row11_col3" class="data row11 col3" >0.0442</td>
#       <td id="T_9adcb_row11_col4" class="data row11 col4" >0.0345</td>
#       <td id="T_9adcb_row11_col5" class="data row11 col5" >0.0143</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_43ebb_row10_col0, #T_43ebb_row10_col1, #T_43ebb_row10_col2, #T_43ebb_row10_col3, #T_43ebb_row10_col4, #T_43ebb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_43ebb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43ebb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_43ebb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_43ebb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_43ebb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_43ebb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_43ebb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43ebb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43ebb_row0_col0" class="data row0 col0" >147978.4257</td>
#       <td id="T_43ebb_row0_col1" class="data row0 col1" >84421497362.5574</td>
#       <td id="T_43ebb_row0_col2" class="data row0 col2" >290553.7771</td>
#       <td id="T_43ebb_row0_col3" class="data row0 col3" >0.9267</td>
#       <td id="T_43ebb_row0_col4" class="data row0 col4" >0.2332</td>
#       <td id="T_43ebb_row0_col5" class="data row0 col5" >0.1853</td>
#     </tr>
#     <tr>
#       <th id="T_43ebb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43ebb_row1_col0" class="data row1 col0" >173972.0395</td>
#       <td id="T_43ebb_row1_col1" class="data row1 col1" >256503128357.5767</td>
#       <td id="T_43ebb_row1_col2" class="data row1 col2" >506461.3789</td>
#       <td id="T_43ebb_row1_col3" class="data row1 col3" >0.8258</td>
#       <td id="T_43ebb_row1_col4" class="data row1 col4" >0.2181</td>
#       <td id="T_43ebb_row1_col5" class="data row1 col5" >0.1636</td>
#     </tr>
#     <tr>
#       <th id="T_43ebb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_43ebb_row2_col0" class="data row2 col0" >178836.9719</td>
#       <td id="T_43ebb_row2_col1" class="data row2 col1" >122905694844.3458</td>
#       <td id="T_43ebb_row2_col2" class="data row2 col2" >350579.0850</td>
#       <td id="T_43ebb_row2_col3" class="data row2 col3" >0.9114</td>
#       <td id="T_43ebb_row2_col4" class="data row2 col4" >0.2479</td>
#       <td id="T_43ebb_row2_col5" class="data row2 col5" >0.1975</td>
#     </tr>
#     <tr>
#       <th id="T_43ebb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_43ebb_row3_col0" class="data row3 col0" >160638.6966</td>
#       <td id="T_43ebb_row3_col1" class="data row3 col1" >111404773527.5676</td>
#       <td id="T_43ebb_row3_col2" class="data row3 col2" >333773.5363</td>
#       <td id="T_43ebb_row3_col3" class="data row3 col3" >0.8752</td>
#       <td id="T_43ebb_row3_col4" class="data row3 col4" >0.2366</td>
#       <td id="T_43ebb_row3_col5" class="data row3 col5" >0.1880</td>
#     </tr>
#     <tr>
#       <th id="T_43ebb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_43ebb_row4_col0" class="data row4 col0" >143640.8523</td>
#       <td id="T_43ebb_row4_col1" class="data row4 col1" >80075506117.4300</td>
#       <td id="T_43ebb_row4_col2" class="data row4 col2" >282976.1582</td>
#       <td id="T_43ebb_row4_col3" class="data row4 col3" >0.9419</td>
#       <td id="T_43ebb_row4_col4" class="data row4 col4" >0.2192</td>
#       <td id="T_43ebb_row4_col5" class="data row4 col5" >0.1773</td>
#     </tr>
#     <tr>
#       <th id="T_43ebb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_43ebb_row5_col0" class="data row5 col0" >156939.9362</td>
#       <td id="T_43ebb_row5_col1" class="data row5 col1" >103275120012.0924</td>
#       <td id="T_43ebb_row5_col2" class="data row5 col2" >321364.4660</td>
#       <td id="T_43ebb_row5_col3" class="data row5 col3" >0.9036</td>
#       <td id="T_43ebb_row5_col4" class="data row5 col4" >0.2450</td>
#       <td id="T_43ebb_row5_col5" class="data row5 col5" >0.1820</td>
#     </tr>
#     <tr>
#       <th id="T_43ebb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_43ebb_row6_col0" class="data row6 col0" >167754.1350</td>
#       <td id="T_43ebb_row6_col1" class="data row6 col1" >314650704484.7026</td>
#       <td id="T_43ebb_row6_col2" class="data row6 col2" >560937.3445</td>
#       <td id="T_43ebb_row6_col3" class="data row6 col3" >0.8113</td>
#       <td id="T_43ebb_row6_col4" class="data row6 col4" >0.2778</td>
#       <td id="T_43ebb_row6_col5" class="data row6 col5" >0.2460</td>
#     </tr>
#     <tr>
#       <th id="T_43ebb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_43ebb_row7_col0" class="data row7 col0" >170510.4320</td>
#       <td id="T_43ebb_row7_col1" class="data row7 col1" >136195015683.0136</td>
#       <td id="T_43ebb_row7_col2" class="data row7 col2" >369046.0888</td>
#       <td id="T_43ebb_row7_col3" class="data row7 col3" >0.8931</td>
#       <td id="T_43ebb_row7_col4" class="data row7 col4" >0.2533</td>
#       <td id="T_43ebb_row7_col5" class="data row7 col5" >0.1985</td>
#     </tr>
#     <tr>
#       <th id="T_43ebb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_43ebb_row8_col0" class="data row8 col0" >144799.6246</td>
#       <td id="T_43ebb_row8_col1" class="data row8 col1" >92452185264.1786</td>
#       <td id="T_43ebb_row8_col2" class="data row8 col2" >304059.5094</td>
#       <td id="T_43ebb_row8_col3" class="data row8 col3" >0.9050</td>
#       <td id="T_43ebb_row8_col4" class="data row8 col4" >0.2400</td>
#       <td id="T_43ebb_row8_col5" class="data row8 col5" >0.1909</td>
#     </tr>
#     <tr>
#       <th id="T_43ebb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_43ebb_row9_col0" class="data row9 col0" >159384.3266</td>
#       <td id="T_43ebb_row9_col1" class="data row9 col1" >78480730247.8323</td>
#       <td id="T_43ebb_row9_col2" class="data row9 col2" >280144.1241</td>
#       <td id="T_43ebb_row9_col3" class="data row9 col3" >0.9384</td>
#       <td id="T_43ebb_row9_col4" class="data row9 col4" >0.2604</td>
#       <td id="T_43ebb_row9_col5" class="data row9 col5" >0.2100</td>
#     </tr>
#     <tr>
#       <th id="T_43ebb_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_43ebb_row10_col0" class="data row10 col0" >160445.5440</td>
#       <td id="T_43ebb_row10_col1" class="data row10 col1" >138036435590.1297</td>
#       <td id="T_43ebb_row10_col2" class="data row10 col2" >359989.5468</td>
#       <td id="T_43ebb_row10_col3" class="data row10 col3" >0.8933</td>
#       <td id="T_43ebb_row10_col4" class="data row10 col4" >0.2431</td>
#       <td id="T_43ebb_row10_col5" class="data row10 col5" >0.1939</td>
#     </tr>
#     <tr>
#       <th id="T_43ebb_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_43ebb_row11_col0" class="data row11 col0" >11713.2508</td>
#       <td id="T_43ebb_row11_col1" class="data row11 col1" >76964744372.4886</td>
#       <td id="T_43ebb_row11_col2" class="data row11 col2" >91891.0320</td>
#       <td id="T_43ebb_row11_col3" class="data row11 col3" >0.0420</td>
#       <td id="T_43ebb_row11_col4" class="data row11 col4" >0.0173</td>
#       <td id="T_43ebb_row11_col5" class="data row11 col5" >0.0211</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Hold-out Evaluation Table

# %%
candidates = tuned_models + [blended, stacked]
rows = []
for m in candidates:
    _ = predict_model(m)
    metrics = pull().iloc[-1].to_dict()
    rows.append({"model": str(m), **metrics})

holdout_df = pd.DataFrame(rows).sort_values("R2", ascending=False)
holdout_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_d1143">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1143_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d1143_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d1143_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d1143_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d1143_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d1143_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d1143_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1143_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1143_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_d1143_row0_col1" class="data row0 col1" >162293.9037</td>
#       <td id="T_d1143_row0_col2" class="data row0 col2" >166033167385.4427</td>
#       <td id="T_d1143_row0_col3" class="data row0 col3" >407471.6768</td>
#       <td id="T_d1143_row0_col4" class="data row0 col4" >0.8651</td>
#       <td id="T_d1143_row0_col5" class="data row0 col5" >0.2844</td>
#       <td id="T_d1143_row0_col6" class="data row0 col6" >0.2371</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_afbc6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afbc6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_afbc6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_afbc6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_afbc6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_afbc6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_afbc6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_afbc6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afbc6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_afbc6_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_afbc6_row0_col1" class="data row0 col1" >172713.7188</td>
#       <td id="T_afbc6_row0_col2" class="data row0 col2" >172596035584.0000</td>
#       <td id="T_afbc6_row0_col3" class="data row0 col3" >415446.7812</td>
#       <td id="T_afbc6_row0_col4" class="data row0 col4" >0.8597</td>
#       <td id="T_afbc6_row0_col5" class="data row0 col5" >0.2908</td>
#       <td id="T_afbc6_row0_col6" class="data row0 col6" >0.2504</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e67fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e67fa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e67fa_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e67fa_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e67fa_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e67fa_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e67fa_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e67fa_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e67fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e67fa_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e67fa_row0_col1" class="data row0 col1" >169493.2104</td>
#       <td id="T_e67fa_row0_col2" class="data row0 col2" >158944869512.2779</td>
#       <td id="T_e67fa_row0_col3" class="data row0 col3" >398678.9053</td>
#       <td id="T_e67fa_row0_col4" class="data row0 col4" >0.8708</td>
#       <td id="T_e67fa_row0_col5" class="data row0 col5" >0.2903</td>
#       <td id="T_e67fa_row0_col6" class="data row0 col6" >0.2453</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_fc160">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc160_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fc160_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fc160_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fc160_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fc160_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fc160_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fc160_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc160_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc160_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_fc160_row0_col1" class="data row0 col1" >173159.5543</td>
#       <td id="T_fc160_row0_col2" class="data row0 col2" >211037540771.4932</td>
#       <td id="T_fc160_row0_col3" class="data row0 col3" >459388.2245</td>
#       <td id="T_fc160_row0_col4" class="data row0 col4" >0.8285</td>
#       <td id="T_fc160_row0_col5" class="data row0 col5" >0.2834</td>
#       <td id="T_fc160_row0_col6" class="data row0 col6" >0.2412</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0a92e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a92e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0a92e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0a92e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0a92e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0a92e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0a92e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0a92e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a92e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a92e_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_0a92e_row0_col1" class="data row0 col1" >171501.1951</td>
#       <td id="T_0a92e_row0_col2" class="data row0 col2" >203185137171.5814</td>
#       <td id="T_0a92e_row0_col3" class="data row0 col3" >450760.6207</td>
#       <td id="T_0a92e_row0_col4" class="data row0 col4" >0.8349</td>
#       <td id="T_0a92e_row0_col5" class="data row0 col5" >0.2869</td>
#       <td id="T_0a92e_row0_col6" class="data row0 col6" >0.2453</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_96856">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96856_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_96856_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_96856_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_96856_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_96856_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_96856_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_96856_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96856_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96856_row0_col0" class="data row0 col0" >Voting Regressor</td>
#       <td id="T_96856_row0_col1" class="data row0 col1" >160698.8858</td>
#       <td id="T_96856_row0_col2" class="data row0 col2" >168096878707.3926</td>
#       <td id="T_96856_row0_col3" class="data row0 col3" >409996.1935</td>
#       <td id="T_96856_row0_col4" class="data row0 col4" >0.8634</td>
#       <td id="T_96856_row0_col5" class="data row0 col5" >0.2701</td>
#       <td id="T_96856_row0_col6" class="data row0 col6" >0.2323</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_b680d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b680d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b680d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b680d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b680d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b680d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b680d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b680d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b680d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b680d_row0_col0" class="data row0 col0" >Stacking Regressor</td>
#       <td id="T_b680d_row0_col1" class="data row0 col1" >164227.6258</td>
#       <td id="T_b680d_row0_col2" class="data row0 col2" >136734854717.4399</td>
#       <td id="T_b680d_row0_col3" class="data row0 col3" >369776.7634</td>
#       <td id="T_b680d_row0_col4" class="data row0 col4" >0.8889</td>
#       <td id="T_b680d_row0_col5" class="data row0 col5" >0.2686</td>
#       <td id="T_b680d_row0_col6" class="data row0 col6" >0.2215</td>
#     </tr>
#   </tbody>
# </table>
#                                                model  \
# 6  StackingRegressor(cv=5,\n                  est...
# 2          LGBMRegressor(n_jobs=-1, random_state=42)
# 0  <catboost.core.CatBoostRegressor object at 0x0...
# 5  VotingRegressor(estimators=[('CatBoost Regress...
# 1  XGBRegressor(base_score=None, booster='gbtree'...
# 4  RandomForestRegressor(n_jobs=-1, random_state=42)
# 3    ExtraTreesRegressor(n_jobs=-1, random_state=42)
#
#                              Model           MAE           MSE          RMSE  \
# 6               Stacking Regressor  164227.62580  1.367349e+11  369776.76340
# 2  Light Gradient Boosting Machine  169493.21040  1.589449e+11  398678.90530
# 0               CatBoost Regressor  162293.90370  1.660332e+11  407471.67680
# 5                 Voting Regressor  160698.88580  1.680969e+11  409996.19350
# 1        Extreme Gradient Boosting  172713.71875  1.725960e+11  415446.78125
# 4          Random Forest Regressor  171501.19510  2.031851e+11  450760.62070
# 3            Extra Trees Regressor  173159.55430  2.110375e+11  459388.22450
#
#        R2   RMSLE    MAPE
# 6  0.8889  0.2686  0.2215
# 2  0.8708  0.2903  0.2453
# 0  0.8651  0.2844  0.2371
# 5  0.8634  0.2701  0.2323
# 1  0.8597  0.2908  0.2504
# 4  0.8349  0.2869  0.2453
# 3  0.8285  0.2834  0.2412

# %% [markdown]
# ## Finalize, Save, and Log the Champion Model
# - Champion: **Stacking Regressor** (highest R² on hold-out).
# - Action:
#   1) `finalize_model()` to fit on all available data inside the PyCaret session.
#   2) Save the full pipeline to `../models/usedcar_price_model.pkl`.
#   3) Log artifacts and metrics to MLflow (same experiment).

# %%
# --- pick the tuned CatBoost from your tuned_models list ---
cat_list = [m for m in tuned_models if "CatBoost" in str(m)]
if cat_list:
    best_cat = cat_list[0]
else:
    best_cat = tune_model(create_model("catboost"), optimize="R2")

# Finalize on full data (train on all rows within the PyCaret session)
final_champion = finalize_model(best_cat)

# ---- Pull metrics WITHOUT calling predict_model (avoid CatBoost name-order issue) ----
# Prefer metrics from your holdout table
import numpy as np, json, mlflow
from pathlib import Path

if 'holdout_df' in globals():
    row = (holdout_df[holdout_df['Model'].str.contains('CatBoost', na=False)]
           .head(1))
    if not row.empty:
        best_metrics = row.iloc[0][['MAE','MSE','RMSE','R2','RMSLE','MAPE']].to_dict()
    else:
        best_metrics = {}   # fallback: no metrics available
else:
    best_metrics = {}

# ---- Save model pipeline ----
models_dir = Path("../models"); models_dir.mkdir(parents=True, exist_ok=True)
save_path = models_dir / "usedcar_price_model"
save_model(final_champion, str(save_path))   # -> ../models/usedcar_price_model.pkl

# ---- Log to MLflow ----
with mlflow.start_run(run_name="champion_finalize_catboost"):
    # Log metrics if we have them
    for k, v in best_metrics.items():
        try:
            if isinstance(v, (int, float, np.floating)):
                mlflow.log_metric(k, float(v))
        except Exception:
            pass

    # Optional leaderboards if present
    for p in [models_dir / "compare_leaderboard.csv",
              models_dir / "tune_leaderboard.csv",
              models_dir / "holdout_results.csv"]:
        try:
            mlflow.log_artifact(str(p), artifact_path="tables")
        except Exception:
            pass

    # Log the model + input schema
    mlflow.log_artifact(f"{save_path}.pkl", artifact_path="model")
    schema = {
        "numeric_features": ["Year","Age","Kilometers_Driven","Log_Km","Mileage","Engine","Power","Seats"],
        "categorical_features": ["Fuel_Type","Transmission","Owner_Type","Location","Brand_Model","Brand"],
        "target": "Price"
    }
    schema_path = models_dir / "input_schema.json"
    with open(schema_path, "w") as f:
        json.dump(schema, f, indent=2)
    mlflow.log_artifact(str(schema_path), artifact_path="model")

print("Champion (CatBoost) saved at:", f"{save_path}.pkl")
print("Metrics (from holdout) logged to MLflow under run: champion_finalize_catboost")
print("View with:")
print("   mlflow ui --backend-store-uri .\\mlruns --host 127.0.0.1 --port 5001")
print("   then open http://127.0.0.1:5001")
# Out:
# Transformation Pipeline and Model Successfully Saved
# Champion (CatBoost) saved at: ..\models\usedcar_price_model.pkl
# Metrics (from holdout) logged to MLflow under run: champion_finalize_catboost
# View with:
#    mlflow ui --backend-store-uri .\mlruns --host 127.0.0.1 --port 5001
#    then open http://127.0.0.1:5001
